# %% [markdown]
# ## In this notebook:
#
# #### We concatenate parcellated PET images into region x receptor matrix of densities.
# Adapted from Hansen Receptors (https://github.com/netneurolab/hansen_receptors)
# Paper: https://www.nature.com/articles/s41593-022-01186-3

# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import pandas as pd
from netneurotools import datasets, plotting
from matplotlib.colors import ListedColormap
from scipy.stats import zscore
from nilearn.datasets import fetch_atlas_schaefer_2018
from netneurotools.datasets import fetch_cammoun2012
import nibabel as nib

# %%
import surfer

# %% [markdown]
# ### Set Variables

# %%
path = '/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/'
datapath = '/Users/pecsok/projects/Neuromaps/hansen_receptors/'
figpath = "/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/data/parcellated/PET_parcellated/desikan_killiany/"
#'/Users/pecsok/Desktop/ImageData/PMACS_remote/data/nmaps/analyses/figures/'

outpath = "/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/data/parcellated/PET_parcellated/desikan_killiany/"
atlas = 'desikan'

if atlas == 'schaefer':
    schaefer = fetch_atlas_schaefer_2018(n_rois=1000, yeo_networks=17) # This is sklearn.utils._bunch.Bunch. Other altases in this format? *Ask Golia
    nnodes = len(schaefer['labels'])
elif atlas == 'cammoun':
    scale = 'cammoun2012_scale500' #'scale1000_17' #'Harvard_Oxford_sub' 
    folder = 'atl-Cammoun2012_res-500'
    cammoun = fetch_cammoun2012()
    nnodes=1015
elif atlas == 'Harvard_Oxford_sub':
    nnodes = 21
elif atlas == 'desikan':
    nnodes = 112
    scale = 'desikan_killiany'
    desikan = '~/Desktop/desikan-killiany_aparcaseg.nii.gz'
    #desikan = '/Users/pecsok/nilearn_data/desikan_killiany/desikan-killiany2006_rois_1mm.nii.gz'
    atlas = 'desikan'
    parcel_file_path = '/Users/pecsok/nilearn_data/desikan_killiany/desikanKillianyNodeNames.txt'
    labels = pd.read_csv(parcel_file_path, header=None, names=['ParcelName'])
    
    lannot = '/Users/pecsok/Desktop/lh.aparc.DKTatlas.annot'
    rannot = '/Users/pecsok/Desktop/rh.aparc.DKTatlas.annot'
    labels_lh, ctab_lh, names_lh = nib.freesurfer.read_annot(lannot)
    labels_rh, ctab_rh, names_rh = nib.freesurfer.read_annot(rannot)
    hemispheres = ['Left'] * len(names_lh) + ['Right'] * len(names_rh)
    names = names_lh + names_rh
    #print(names)
    labels2 = pd.DataFrame({'ParcelName': names, 'Hemisphere': hemispheres})
    print(labels2)
    labels2['ParcelName'] = labels2['ParcelName'].apply(lambda x: x.decode('utf-8'))
    print(labels2)
# Out:
#                     ParcelName Hemisphere
# 0                   b'unknown'       Left
# 1                  b'bankssts'       Left
# 2   b'caudalanteriorcingulate'       Left
# 3       b'caudalmiddlefrontal'       Left
# 4            b'corpuscallosum'       Left
# ..                         ...        ...
# 67            b'supramarginal'      Right
# 68              b'frontalpole'      Right
# 69             b'temporalpole'      Right
# 70       b'transversetemporal'      Right
# 71                   b'insula'      Right
#
# [72 rows x 2 columns]
#                  ParcelName Hemisphere
# 0                   unknown       Left
# 1                  bankssts       Left
# 2   caudalanteriorcingulate       Left
# 3       caudalmiddlefrontal       Left
# 4            corpuscallosum       Left
# ..                      ...        ...
# 67            supramarginal      Right
# 68              frontalpole      Right
# 69             temporalpole      Right
# 70       transversetemporal      Right
# 71                   insula      Right
#
# [72 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)
#print(labels)

cortical = pd.read_csv("~/Desktop/cortical_significance_analysis.csv", sep=',')
subcortical = pd.read_csv("~/Desktop/subcortical_significance_analysis.csv", sep=',')

# %% [markdown]
# ### Choose what to analyse

# %% [markdown]
# ### Make Receptor Matrices

# %%
print(scale) #pecsok_pfns/neuromaps/data/parcellated/PET_parcellated/"+scale+"
# Out:
# desikan_killiany

# %%
#print(receptors_csv)
pd.set_option('display.max_rows', None)

# %%
#print(labels)

# %%
# Create annoying loop to reframe df to make equivalent of receptor_df

voldf = pd.DataFrame(index=labels['ParcelName'], columns=['Hemisphere','Volume_change','Pvalue']).fillna(0)

#print(voldf)
for i, roi in enumerate(cortical['ROI']):
    parts = roi.split('_')
    hemi = parts[0]
    string = parts[1]
    for j in range(len(voldf)):
        region = str(voldf.index[j])
        
        # Check if the extracted string is in the index of voldf
        if string.lower() in region.lower() and hemi.lower() in region.lower():
            # Add the corresponding volume to voldf
            value = cortical.loc[i, 'Estimate']
            p = cortical.loc[i, 'P.Value']
            voldf.at[region, 'Volume_change'] = value  # Use 'at' for fast scalar access
            voldf.at[region, 'Hemisphere'] = hemi
            voldf.at[region, 'Pvalue'] = p

# Subcortical
for i, roi in enumerate(subcortical['ROI']):
    parts = roi.split('.')
    hemi = parts[0]
    string = parts[1]
    print(string)
    for j in range(len(voldf)):
        region = str(voldf.index[j])
        
        # Check if the extracted string is in the index of voldf
        if string.lower() in region.lower() and hemi.lower() in region.lower():
            # Add the corresponding volume to voldf
            value = subcortical.loc[i, 'Estimate']
            p = cortical.loc[i, 'P.Value']
            voldf.at[region, 'Volume_change'] = value  # Use 'at' for fast scalar access
            voldf.at[region, 'Hemisphere'] = hemi
            voldf.at[region, 'Pvalue'] = p
            
# Display the resulting DataFrame
display(voldf)
# Out:
# Cerebellum
# Thalamus
# Caudate
# Putamen
# Pallidum
# Hippocampus
# Amygdala
# Accumbens
# VentralDC
# Cerebellum
# Thalamus
# Caudate
# Putamen
# Pallidum
# Hippocampus
# Amygdala
# Accumbens
# VentralDC
# Posterior
# Mid_Posterior
# Central
# Mid_Anterior
# Anterior
# /var/folders/kk/w6xmtt2d55xfbxvb6wcqhq580000gp/T/ipykernel_67104/1880600848.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   voldf = pd.DataFrame(index=labels['ParcelName'], columns=['Hemisphere','Volume_change','Pvalue']).fillna(0)
# /var/folders/kk/w6xmtt2d55xfbxvb6wcqhq580000gp/T/ipykernel_67104/1880600848.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '627.2975405' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   voldf.at[region, 'Volume_change'] = value  # Use 'at' for fast scalar access
# /var/folders/kk/w6xmtt2d55xfbxvb6wcqhq580000gp/T/ipykernel_67104/1880600848.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'lh' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   voldf.at[region, 'Hemisphere'] = hemi
# /var/folders/kk/w6xmtt2d55xfbxvb6wcqhq580000gp/T/ipykernel_67104/1880600848.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.48e-10' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   voldf.at[region, 'Pvalue'] = p
#                                 Hemisphere  Volume_change        Pvalue
# ParcelName
# Left-Cerebral-White-Matter               0       0.000000  0.000000e+00
# Left-Lateral-Ventricle                   0       0.000000  0.000000e+00
# Left-Inf-Lat-Vent                        0       0.000000  0.000000e+00
# Left-Cerebellum-White-Matter          Left    6680.831629  8.480000e-10
# Left-Cerebellum-Cortex                Left    6680.831629  8.480000e-10
# Left-Thalamus-Proper                  Left    1673.816025  2.390010e-04
# Left-Caudate                          Left     585.087394  5.790000e-12
# Left-Putamen                          Left    1209.638209  8.720000e-07
# Left-Pallidum                         Left     262.890897  1.720425e-01
# 3rd-Ventricle                            0       0.000000  0.000000e+00
# 4th-Ventricle                            0       0.000000  0.000000e+00
# Brain-Stem                               0       0.000000  0.000000e+00
# Left-Hippocampus                      Left     548.420802  6.990000e-13
# Left-Amygdala                         Left     308.856041  1.320000e-17
# CSF                                      0       0.000000  0.000000e+00
# Left-Accumbens-area                   Left     262.574095  1.540000e-12
# Left-VentralDC                        Left     631.041615  5.260000e-10
# Left-vessel                              0       0.000000  0.000000e+00
# Left-choroid-plexus                      0       0.000000  0.000000e+00
# Right-Cerebral-White-Matter              0       0.000000  0.000000e+00
# Right-Lateral-Ventricle                  0       0.000000  0.000000e+00
# Right-Inf-Lat-Vent                       0       0.000000  0.000000e+00
# Right-Cerebellum-White-Matter        Right    5817.017260  1.980000e-12
# Right-Cerebellum-Cortex              Right    5817.017260  1.980000e-12
# Right-Thalamus-Proper                Right    1505.477519  2.040000e-16
# Right-Caudate                        Right     657.572561  2.650000e-11
# Right-Putamen                        Right    1198.752252  3.420000e-08
# Right-Pallidum                       Right     203.725268  4.100000e-22
# Right-Hippocampus                    Right     501.780960  8.800000e-10
# Right-Amygdala                       Right     247.919440  1.010000e-09
# Right-Accumbens-area                 Right     208.092131  2.260000e-13
# Right-VentralDC                      Right     710.859645  1.850000e-15
# Right-vessel                             0       0.000000  0.000000e+00
# Right-choroid-plexus                     0       0.000000  0.000000e+00
# WM-hypointensities                       0       0.000000  0.000000e+00
# non-WM-hypointensities                   0       0.000000  0.000000e+00
# Optic-Chiasm                             0       0.000000  0.000000e+00
# CC_Posterior                            CC    -104.458678  7.650000e-20
# CC_Mid_Posterior                        CC     -21.089419  4.980000e-10
# CC_Central                              CC      86.087399  1.490000e-12
# CC_Mid_Anterior                         CC       4.176435  1.400000e-14
# CC_Anterior                             CC       4.176435  1.400000e-14
# ctx-lh-unknown                           0       0.000000  0.000000e+00
# ctx-lh-bankssts                         lh     627.297540  8.480000e-10
# ctx-lh-caudalanteriorcingulate          lh     353.818611  2.390010e-04
# ctx-lh-caudalmiddlefrontal              lh    1705.133553  5.790000e-12
# ctx-lh-cuneus                           lh     518.331496  8.720000e-07
# ctx-lh-entorhinal                       rh      90.616662  1.729406e-01
# ctx-lh-fusiform                         lh    1555.845503  6.990000e-13
# ctx-lh-inferiorparietal                 lh    3075.813159  1.320000e-17
# ctx-lh-inferiortemporal                 lh    2257.835278  1.540000e-12
# ctx-lh-isthmuscingulate                 lh     469.899523  5.260000e-10
# ctx-lh-lateraloccipital                 lh    2456.105619  1.980000e-12
# ctx-lh-lateralorbitofrontal             lh    1618.248945  2.040000e-16
# ctx-lh-lingual                          lh    1422.773133  2.650000e-11
# ctx-lh-medialorbitofrontal              lh     635.745270  3.420000e-08
# ctx-lh-middletemporal                   lh    3358.846299  4.100000e-22
# ctx-lh-parahippocampal                  lh     359.485840  8.800000e-10
# ctx-lh-paracentral                      lh     559.576560  1.010000e-09
# ctx-lh-parsopercularis                  lh    1210.015483  2.260000e-13
# ctx-lh-parsorbitalis                    lh     642.139365  1.850000e-15
# ctx-lh-parstriangularis                 lh    1207.826275  7.650000e-20
# ctx-lh-pericalcarine                    lh     592.468724  4.980000e-10
# ctx-lh-postcentral                      lh    1886.543561  1.490000e-12
# ctx-lh-posteriorcingulate               lh     843.569003  4.970000e-19
# ctx-lh-precentral                       lh    2582.994288  1.400000e-14
# ctx-lh-precuneus                        lh    2280.890147  5.980000e-19
# ctx-lh-rostralanteriorcingulate         lh     700.837363  7.770000e-14
# ctx-lh-rostralmiddlefrontal             lh    4277.720070  8.580000e-19
# ctx-lh-superiorfrontal                  lh    5444.804259  1.670000e-20
# ctx-lh-superiorparietal                 lh    2773.927821  2.640000e-15
# ctx-lh-superiortemporal                 lh    3223.847868  6.810000e-21
# ctx-lh-supramarginal                    lh    2861.795207  9.810000e-14
# ctx-lh-frontalpole                      lh     187.226417  7.240000e-09
# ctx-lh-temporalpole                     lh      74.287054  3.554098e-01
# ctx-lh-transversetemporal               lh     209.742840  2.290000e-06
# ctx-lh-insula                           lh     843.639895  2.940000e-08
# ctx-rh-unknown                           0       0.000000  0.000000e+00
# ctx-rh-bankssts                         rh     564.098352  1.150000e-13
# ctx-rh-caudalanteriorcingulate          rh     319.943406  1.506138e-03
# ctx-rh-caudalmiddlefrontal              rh    1767.089422  1.480000e-12
# ctx-rh-cuneus                           rh     613.442792  8.860000e-08
# ctx-rh-entorhinal                       rh      90.616662  1.729406e-01
# ctx-rh-fusiform                         rh    1861.453686  7.810000e-14
# ctx-rh-inferiorparietal                 rh    4421.842971  1.170000e-22
# ctx-rh-inferiortemporal                 rh    2081.255601  4.270000e-11
# ctx-rh-isthmuscingulate                 rh     513.992032  4.670000e-11
# ctx-rh-lateraloccipital                 rh    2337.638134  8.510000e-13
# ctx-rh-lateralorbitofrontal             rh    1383.974514  2.050000e-13
# ctx-rh-lingual                          rh    1500.505507  5.580000e-11
# ctx-rh-medialorbitofrontal              rh     638.104153  5.880000e-07
# ctx-rh-middletemporal                   rh    3361.606680  7.900000e-22
# ctx-rh-parahippocampal                  rh     378.951460  8.560000e-13
# ctx-rh-paracentral                      rh     642.415991  1.100000e-09
# ctx-rh-parsopercularis                  rh     857.214666  2.350000e-11
# ctx-rh-parsorbitalis                    rh     729.340290  2.410000e-14
# ctx-rh-parstriangularis                 rh    1201.863537  5.640000e-16
# ctx-rh-pericalcarine                    rh     669.425850  2.530000e-10
# ctx-rh-postcentral                      rh    1954.749951  1.480000e-13
# ctx-rh-posteriorcingulate               rh     764.899216  1.570000e-13
# ctx-rh-precentral                       rh    2402.200636  4.680000e-13
# ctx-rh-precuneus                        rh    2249.594056  9.700000e-18
# ctx-rh-rostralanteriorcingulate         rh     432.641222  1.620000e-06
# ctx-rh-rostralmiddlefrontal             rh    4286.031616  1.280000e-17
# ctx-rh-superiorfrontal                  rh    4921.709361  6.720000e-18
# ctx-rh-superiorparietal                 rh    3007.676366  1.200000e-16
# ctx-rh-superiortemporal                 rh    2769.693478  1.150000e-19
# ctx-rh-supramarginal                    rh    2775.430795  4.230000e-18
# ctx-rh-frontalpole                      rh      63.506141  1.087333e-01
# ctx-rh-temporalpole                     rh     289.525611  2.105106e-03
# ctx-rh-transversetemporal               rh     183.930180  1.530000e-07
# ctx-rh-insula                           rh     955.243019  1.990000e-10

# %%
#Trim Voldf and only keep values that are in annot file
#


#print(voldf)

# Make new column for values
labels2['Volume_change'] = np.nan

print(labels2['ParcelName'])

# Loop through voldf and add correct data to correct row
for i, roi in enumerate(voldf.index):
    # Extract region string
    parts = roi.split('-')
    hemi = parts[0]
    if len(parts) > 1:
        string = parts[1]
    else:
        continue
    for j, surf_roi in enumerate(labels2['ParcelName']):
        # Extract Surface plot region string
        #print(surf_roi)
        if not isinstance(surf_roi, float):
            if string.lower() in surf_roi.lower():
                if pd.isna(labels2.loc[j,'Volume_change']):
                    #print(
                    value = voldf.loc[roi, 'Volume_change']
                    p = voldf.loc[roi, 'Pvalue']
                    labels2.at[j, 'Volume_change'] = value  # Use 'at' for fast scalar access
                    #labels2.at[i, 'Hemisphere'] = hemi
                    labels2.at[j, 'Pvalue'] = p
# Out:
# 0                      unknown
# 1                     bankssts
# 2      caudalanteriorcingulate
# 3          caudalmiddlefrontal
# 4               corpuscallosum
# 5                       cuneus
# 6                   entorhinal
# 7                     fusiform
# 8             inferiorparietal
# 9             inferiortemporal
# 10            isthmuscingulate
# 11            lateraloccipital
# 12        lateralorbitofrontal
# 13                     lingual
# 14         medialorbitofrontal
# 15              middletemporal
# 16             parahippocampal
# 17                 paracentral
# 18             parsopercularis
# 19               parsorbitalis
# 20            parstriangularis
# 21               pericalcarine
# 22                 postcentral
# 23          posteriorcingulate
# 24                  precentral
# 25                   precuneus
# 26    rostralanteriorcingulate
# 27        rostralmiddlefrontal
# 28             superiorfrontal
# 29            superiorparietal
# 30            superiortemporal
# 31               supramarginal
# 32                 frontalpole
# 33                temporalpole
# 34          transversetemporal
# 35                      insula
# 36                     unknown
# 37                    bankssts
# 38     caudalanteriorcingulate
# 39         caudalmiddlefrontal
# 40              corpuscallosum
# 41                      cuneus
# 42                  entorhinal
# 43                    fusiform
# 44            inferiorparietal
# 45            inferiortemporal
# 46            isthmuscingulate
# 47            lateraloccipital
# 48        lateralorbitofrontal
# 49                     lingual
# 50         medialorbitofrontal
# 51              middletemporal
# 52             parahippocampal
# 53                 paracentral
# 54             parsopercularis
# 55               parsorbitalis
# 56            parstriangularis
# 57               pericalcarine
# 58                 postcentral
# 59          posteriorcingulate
# 60                  precentral
# 61                   precuneus
# 62    rostralanteriorcingulate
# 63        rostralmiddlefrontal
# 64             superiorfrontal
# 65            superiorparietal
# 66            superiortemporal
# 67               supramarginal
# 68                 frontalpole
# 69                temporalpole
# 70          transversetemporal
# 71                      insula
# Name: ParcelName, dtype: object
# "   \n\nfor i, roi in enumerate(cortical['ROI']):\n    parts = roi.split('_')\n    hemi = parts[0]\n    string = parts[1]\n    for j in range(len(voldf)):\n        region = str(voldf.index[j])\n        \n        # Check if the extracted string is in the index of voldf\n        if string.lower() in region.lower() and hemi.lower() in region.lower():\n            # Add the corresponding volume to voldf\n            value = cortical.loc[i, 'Estimate']\n            p = cortical.loc[i, 'P.Value']\n            voldf.at[region, 'Volume_change'] = value  # Use 'at' for fast scalar access\n            voldf.at[region, 'Hemisphere'] = hemi\n            voldf.at[region, 'Pvalue'] = p\n\n\n   \n            if string.lower() in region.lower() and hemi.lower() in region.lower():\n            # Add the corresponding volume to voldf\n            value = cortical.loc[i, 'Estimate']\n            p = cortical.loc[i, 'P.Value']\n            voldf.at[region, 'Volume_change'] = value  # Use 'at' for fast scalar access\n            voldf.at[region, 'Hemisphere'] = hemi\n\n\n    \n    \n    \n    for j in range(len(voldf)):\n        region = str(voldf.index[j])\n"

# %%
print(labels2)
# Out:
#                    ParcelName Hemisphere  Volume_change        Pvalue
# 0                     unknown       Left            NaN           NaN
# 1                    bankssts       Left       0.000000  0.000000e+00
# 2     caudalanteriorcingulate       Left       0.000000  0.000000e+00
# 3         caudalmiddlefrontal       Left            NaN           NaN
# 4              corpuscallosum       Left            NaN           NaN
# 5                      cuneus       Left            NaN           NaN
# 6                  entorhinal       Left            NaN           NaN
# 7                    fusiform       Left            NaN           NaN
# 8            inferiorparietal       Left            NaN           NaN
# 9            inferiortemporal       Left            NaN           NaN
# 10           isthmuscingulate       Left            NaN           NaN
# 11           lateraloccipital       Left            NaN           NaN
# 12       lateralorbitofrontal       Left            NaN           NaN
# 13                    lingual       Left            NaN           NaN
# 14        medialorbitofrontal       Left            NaN           NaN
# 15             middletemporal       Left            NaN           NaN
# 16            parahippocampal       Left            NaN           NaN
# 17                paracentral       Left            NaN           NaN
# 18            parsopercularis       Left            NaN           NaN
# 19              parsorbitalis       Left            NaN           NaN
# 20           parstriangularis       Left       0.000000  0.000000e+00
# 21              pericalcarine       Left       0.000000  0.000000e+00
# 22                postcentral       Left            NaN           NaN
# 23         posteriorcingulate       Left            NaN           NaN
# 24                 precentral       Left            NaN           NaN
# 25                  precuneus       Left            NaN           NaN
# 26   rostralanteriorcingulate       Left            NaN           NaN
# 27       rostralmiddlefrontal       Left            NaN           NaN
# 28            superiorfrontal       Left            NaN           NaN
# 29           superiorparietal       Left            NaN           NaN
# 30           superiortemporal       Left            NaN           NaN
# 31              supramarginal       Left            NaN           NaN
# 32                frontalpole       Left            NaN           NaN
# 33               temporalpole       Left            NaN           NaN
# 34         transversetemporal       Left            NaN           NaN
# 35                     insula       Left            NaN           NaN
# 36                    unknown      Right            NaN           NaN
# 37                   bankssts      Right            NaN           NaN
# 38    caudalanteriorcingulate      Right            NaN           NaN
# 39        caudalmiddlefrontal      Right            NaN           NaN
# 40             corpuscallosum      Right            NaN           NaN
# 41                     cuneus      Right            NaN           NaN
# 42                 entorhinal      Right            NaN           NaN
# 43                   fusiform      Right            NaN           NaN
# 44           inferiorparietal      Right            NaN           NaN
# 45           inferiortemporal      Right            NaN           NaN
# 46           isthmuscingulate      Right            NaN           NaN
# 47           lateraloccipital      Right            NaN           NaN
# 48       lateralorbitofrontal      Right            NaN           NaN
# 49                    lingual      Right            NaN           NaN
# 50        medialorbitofrontal      Right            NaN           NaN
# 51             middletemporal      Right            NaN           NaN
# 52            parahippocampal      Right            NaN           NaN
# 53                paracentral      Right            NaN           NaN
# 54            parsopercularis      Right            NaN           NaN
# 55              parsorbitalis      Right            NaN           NaN
# 56           parstriangularis      Right            NaN           NaN
# 57              pericalcarine      Right            NaN           NaN
# 58                postcentral      Right            NaN           NaN
# 59         posteriorcingulate      Right            NaN           NaN
# 60                 precentral      Right            NaN           NaN
# 61                  precuneus      Right            NaN           NaN
# 62   rostralanteriorcingulate      Right            NaN           NaN
# 63       rostralmiddlefrontal      Right            NaN           NaN
# 64            superiorfrontal      Right            NaN           NaN
# 65           superiorparietal      Right            NaN           NaN
# 66           superiortemporal      Right            NaN           NaN
# 67              supramarginal      Right            NaN           NaN
# 68                frontalpole      Right            NaN           NaN
# 69               temporalpole      Right            NaN           NaN
# 70         transversetemporal      Right            NaN           NaN
# 71                     insula      Right            NaN           NaN
# 77                        NaN        NaN       0.000000  0.000000e+00
# 78                        NaN        NaN     564.098352  1.150000e-13
# 79                        NaN        NaN     319.943406  1.506138e-03
# 80                        NaN        NaN    1767.089422  1.480000e-12
# 81                        NaN        NaN     613.442792  8.860000e-08
# 82                        NaN        NaN      90.616662  1.729406e-01
# 83                        NaN        NaN    1861.453686  7.810000e-14
# 84                        NaN        NaN    4421.842971  1.170000e-22
# 85                        NaN        NaN    2081.255601  4.270000e-11
# 86                        NaN        NaN     513.992032  4.670000e-11
# 87                        NaN        NaN    2337.638134  8.510000e-13
# 88                        NaN        NaN    1383.974514  2.050000e-13
# 89                        NaN        NaN    1500.505507  5.580000e-11
# 90                        NaN        NaN     638.104153  5.880000e-07
# 91                        NaN        NaN    3361.606680  7.900000e-22
# 92                        NaN        NaN     378.951460  8.560000e-13
# 93                        NaN        NaN     642.415991  1.100000e-09
# 94                        NaN        NaN     857.214666  2.350000e-11
# 95                        NaN        NaN     729.340290  2.410000e-14
# 96                        NaN        NaN    1201.863537  5.640000e-16
# 97                        NaN        NaN     669.425850  2.530000e-10
# 98                        NaN        NaN    1954.749951  1.480000e-13
# 99                        NaN        NaN     764.899216  1.570000e-13
# 100                       NaN        NaN    2402.200636  4.680000e-13
# 101                       NaN        NaN    2249.594056  9.700000e-18
# 102                       NaN        NaN     432.641222  1.620000e-06
# 103                       NaN        NaN    4286.031616  1.280000e-17
# 104                       NaN        NaN    4921.709361  6.720000e-18
# 105                       NaN        NaN    3007.676366  1.200000e-16
# 106                       NaN        NaN    2769.693478  1.150000e-19
# 107                       NaN        NaN    2775.430795  4.230000e-18
# 108                       NaN        NaN      63.506141  1.087333e-01
# 109                       NaN        NaN     289.525611  2.105106e-03
# 110                       NaN        NaN     183.930180  1.530000e-07
# 111                       NaN        NaN     955.243019  1.990000e-10

# %%
# VERSION 2 with aparc regions 
voldf = pd.DataFrame(index=labels['ParcelName'], columns=['Volume_change','Pvalue']).fillna(0)
hemispheres = ['Left'] * 36 + ['Right'] * 36
voldf['Hemisphere'] = hemispheres

#print(voldf)
#print(labels.shape)

#print(voldf)
for i, roi in enumerate(cortical['ROI']):
    parts = roi.split('_')
    hemi = parts[0]
    string = parts[1]
    for j in range(len(voldf)):
        #region = str(voldf.index[j])
        region = voldf.loc[j, 'Hemisphere']
        
        # Check if the extracted string is in the index of voldf
        if string.lower() in region.lower() and hemi.lower() in region.lower():
            # Add the corresponding volume to voldf
            value = cortical.loc[i, 'Estimate']
            p = cortical.loc[i, 'P.Value']
            voldf.at[region, 'Volume_change'] = value  # Use 'at' for fast scalar access
            voldf.at[region, 'Hemisphere'] = hemi
            voldf.at[region, 'Pvalue'] = p

# Subcortical
for i, roi in enumerate(subcortical['ROI']):
    parts = roi.split('.')
    hemi = parts[0]
    string = parts[1]
    print(string)
    for j in range(len(voldf)):
        region = str(voldf.index[j])
        
        # Check if the extracted string is in the index of voldf
        if string.lower() in region.lower() and hemi.lower() in region.lower():
            # Add the corresponding volume to voldf
            value = subcortical.loc[i, 'Estimate']
            p = cortical.loc[i, 'P.Value']
            voldf.at[region, 'Volume_change'] = value  # Use 'at' for fast scalar access
            voldf.at[region, 'Hemisphere'] = hemi
            voldf.at[region, 'Pvalue'] = p
            
# Display the resulting DataFrame
display(voldf)
# Out:
# /var/folders/kk/w6xmtt2d55xfbxvb6wcqhq580000gp/T/ipykernel_67104/2912069668.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   voldf = pd.DataFrame(index=labels['ParcelName'], columns=['Volume_change','Pvalue']).fillna(0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 voldf = pd.DataFrame(index=labels['ParcelName'], columns=['Volume_change','Pvalue']).fillna(0)
#       3 hemispheres = ['Left'] * 36 + ['Right'] * 36
# ----> 4 voldf['Hemisphere'] = hemispheres
#       6 #print(voldf)
#       7 #print(labels.shape)
#       8
#       9 #print(voldf)
#      10 for i, roi in enumerate(cortical['ROI']):
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (72) does not match length of index (112)

# %%
# combine all the receptors (including repeats)
r = np.zeros([nnodes, len(receptors_csv)])
print(r.shape)
for i in range(len(receptors_csv)):
    r[:, i] = np.genfromtxt(receptors_csv[i], delimiter=',') 
    # Now we have the receptor data by parcel (row) for all 6 receptor maps (col)
    

#print(r[:,3])
print(r.shape)

receptor_names = np.array(["5HT1a", "5HT1b", "5HT2a", "5HT4", "5HT6", "5HTT", "A4B2",
                           "CB1", "D1", "D2", "DAT", "GABAa", "H3", "M1", "mGluR5",
                           "MOR", "NET", "NMDA", "VAChT"])
#np.save(path+'data/receptor_names_pet.npy', receptor_names)

# make final region x receptor matrix
receptor_data = np.zeros([nnodes, len(receptor_names)])

# Add 5HT1a Data
receptor_data[:, 0] = zscore(r[:, 0]) 
# Add "5HT2a", "5HT4", "5HT6", "5HTT", "A4B2", "CB1", "D1"
receptor_data[:, 2:9] = zscore(r[:, 3:10])
# Add "DAT", "GABAa", "H3", "M1"
receptor_data[:, 10:14] = zscore(r[:, 12:16])
# Add "MOR", "NET", "NMDA"
receptor_data[:, 15:18] = zscore(r[:, 19:22])

# weighted average of 5HT1B p943
receptor_data[:, 1] = (zscore(r[:, 1])*22 + zscore(r[:, 2])*65) / (22+65)
# weighted average of D2 flb457
receptor_data[:, 9] = (zscore(r[:, 10])*37 + zscore(r[:, 11])*55) / (37+55)
# weighted average of mGluR5 ABP688
receptor_data[:, 14] = (zscore(r[:, 16])*22 + zscore(r[:, 17])*28 + zscore(r[:, 18])*73) / (22+28+73)
# weighted average of VAChT FEOBV
receptor_data[:, 18] = (zscore(r[:, 22])*4 + zscore(r[:, 23])*5 + zscore(r[:, 24])*18) / (4+5+18)

print(receptors_csv[0]) #5HT1a

# Make df and add parcel labels
receptor_df = pd.DataFrame(receptor_data, columns=receptor_names,index=labels)

"""
#schaefer = fetch_atlas_schaefer_2018(n_rois=1000, yeo_networks=17)
#labels = schaefer.labels
#labels = [label.decode('utf-8') for label in labels]
cam = fetch_cammoun2012()
info = pd.read_csv(cammoun['info'], sep=',')
info = info[info['scale']== 'scale500']
hemisphere = info['hemisphere'].values
labels = info['label'].values + hemisphere
print(labels)
"""

receptor_df.index = labels
receptor_df.index.name = 'Parcel'

#print(receptor_df)
# Save df
receptor_df.to_csv(path+'results/receptor_data_'+scale+'.csv', index=True, header=True)
# Out:
# (112, 25)
# (112, 25)
# /Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/data/parcellated/PET_parcellated/desikan_killiany/5HT1a_way_hc36_savli.csv

# %%
cammoun = fetch_cammoun2012()
cam = fetch_cammoun2012()
info = pd.read_csv(cammoun['info'], sep=',')
info = info[info['scale']== 'scale060']
hemisphere = info['hemisphere'].values
labels = info['label'].values + hemisphere
print(labels.shape)
# Out:
# (129,)

# %%
# Make vol change image
r = np.zeros([nnodes, 1])
print(r.shape)
r[:,0] = voldf['Volume_change']

vol_data = r
# Out:
# (112, 1)

# %%
"""
plot receptor data
"""

## NEWWWWWW
if scale == 'cammoun2012_scale500':
    cammoun = datasets.fetch_cammoun2012(version='fsaverage')
    cammoun = cammoun['scale500']
    print(cammoun)
    #annot = datasets.fetch_schaefer2018('fsaverage')['100Parcels7Networks']
    for k in range(len(receptor_names)):
        brain = plotting.plot_fsaverage(data=receptor_data[:, k],
                                        lhannot = cammoun[0],
                                        rhannot = cammoun[1],
                                        colormap='plasma',
                                        views=['lat', 'med'],
                                        data_kws={'representation': "wireframe"})
        brain.save_image(figpath + folder + '/surface_receptor_'+receptor_names[k]+'.png')




#receptor_data[:, 2:9] = r[:, 3:10]
print(receptor_data)
print(len(receptor_data))

print(r)
# Out:
# Surface(lh='/Users/pecsok/nnt-data/atl-cammoun2012/fsaverage/atl-Cammoun2012_space-fsaverage_res-500_hemi-L_deterministic.annot', rh='/Users/pecsok/nnt-data/atl-cammoun2012/fsaverage/atl-Cammoun2012_space-fsaverage_res-500_hemi-R_deterministic.annot')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[84], line 58
#      56     #annot = datasets.fetch_schaefer2018('fsaverage')['100Parcels7Networks']
#      57     for k in range(len(receptor_names)):
# ---> 58         brain = plotting.plot_fsaverage(data=receptor_data[:, k],
#      59                                         lhannot = cammoun[0],
#      60                                         rhannot = cammoun[1],
#      61                                         colormap='plasma',
#      62                                         views=['lat', 'med'],
#      63                                         data_kws={'representation': "wireframe"})
#      64         brain.save_image(figpath + folder + '/surface_receptor_'+receptor_names[k]+'.png')
#      70 #receptor_data[:, 2:9] = r[:, 3:10]
#
# File ~/.local/lib/python3.11/site-packages/netneurotools/plotting.py:560, in plot_fsaverage(data, lhannot, rhannot, order, mask, noplot, subject_id, subjects_dir, vmin, vmax, **kwargs)
#     558 for i in inds:
#     559     hemidata = np.insert(hemidata, i, np.nan)
# --> 560 vtx = hemidata[labels]
#     562 # let's also mask data, if necessary
#     563 if mask is not None:
#
# IndexError: index 146 is out of bounds for axis 0 with size 114

# %%
cammoun = fetch_cammoun2012

# %%
#pip install mne

# %%
# Out:
# Using default location ~/mne_data for sample...
# Creating /Users/pecsok/mne_data
# Downloading file 'MNE-sample-data-processed.tar.gz' from 'https://osf.io/86qa2/download?version=6' to '/Users/pecsok/mne_data'.
#   4%|█▌                                   | 69.8M/1.65G [00:03<00:59, 26.6MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Load fsaverage surface
#       2 import mne
# ----> 3 subjects_dir = mne.datasets.sample.data_path() / 'subjects'
#       4 brain = mne.viz.Brain('fsaverage', 'lh', 'inflated', subjects_dir=subjects_dir)
#       6 # Load parcellation data (e.g., HCPMMP1)
#
# File <decorator-gen-323>:12, in data_path(path, force_update, update_path, download, verbose)
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/site-packages/mne/datasets/sample/sample.py:13, in data_path(path, force_update, update_path, download, verbose)
#       9 @verbose
#      10 def data_path(
#      11     path=None, force_update=False, update_path=True, download=True, *, verbose=None
#      12 ):  # noqa: D103
# ---> 13     return _download_mne_dataset(
#      14         name="sample",
#      15         processor="untar",
#      16         path=path,
#      17         force_update=force_update,
#      18         update_path=update_path,
#      19         download=download,
#      20     )
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/site-packages/mne/datasets/utils.py:242, in _download_mne_dataset(name, processor, path, force_update, update_path, download, accept)
#     237         this_dataset["dataset_name"] = name
#     238         dataset_params.append(this_dataset)
#     240 return cast(
#     241     Path,
# --> 242     fetch_dataset(
#     243         dataset_params=dataset_params,
#     244         processor=processor_,
#     245         path=path,
#     246         force_update=force_update,
#     247         update_path=update_path,
#     248         download=download,
#     249         accept=accept,
#     250     ),
#     251 )
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/site-packages/mne/datasets/_fetch.py:262, in fetch_dataset(dataset_params, processor, path, force_update, update_path, download, check_version, return_version, accept, auth, token)
#     260 archive_name = dataset_params[idx]["archive_name"]
#     261 try:
# --> 262     fetcher.fetch(
#     263         fname=archive_name, downloader=downloader, processor=processor
#     264     )
#     265 except ValueError as err:
#     266     err = str(err)
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/site-packages/pooch/core.py:589, in Pooch.fetch(self, fname, processor, downloader, progressbar)
#     586     if downloader is None:
#     587         downloader = choose_downloader(url, progressbar=progressbar)
# --> 589     stream_download(
#     590         url,
#     591         full_path,
#     592         known_hash,
#     593         downloader,
#     594         pooch=self,
#     595         retry_if_failed=self.retry_if_failed,
#     596     )
#     598 if processor is not None:
#     599     return processor(str(full_path), action, self)
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/site-packages/pooch/core.py:807, in stream_download(url, fname, known_hash, downloader, pooch, retry_if_failed)
#     803 try:
#     804     # Stream the file to a temporary so that we can safely check its
#     805     # hash before overwriting the original.
#     806     with temporary_file(path=str(fname.parent)) as tmp:
# --> 807         downloader(url, tmp, pooch)
#     808         hash_matches(tmp, known_hash, strict=True, source=str(fname.name))
#     809         shutil.move(tmp, str(fname))
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/site-packages/pooch/downloaders.py:240, in HTTPDownloader.__call__(self, url, output_file, pooch, check_only)
#     238     progress = self.progressbar
#     239     progress.total = total
# --> 240 for chunk in content:
#     241     if chunk:
#     242         output_file.write(chunk)
#
# File ~/.local/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:1043, in HTTPResponse.stream(self, amt, decode_content)
#    1041 else:
#    1042     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1043         data = self.read(amt=amt, decode_content=decode_content)
#    1045         if data:
#    1046             yield data
#
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:935, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     932     if len(self._decoded_buffer) >= amt:
#     933         return self._decoded_buffer.get(amt)
# --> 935 data = self._raw_read(amt)
#     937 flush_decoder = amt is None or (amt != 0 and not data)
#     939 if not data and len(self._decoded_buffer) == 0:
#
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:862, in HTTPResponse._raw_read(self, amt, read1)
#     859 fp_closed = getattr(self._fp, "closed", False)
#     861 with self._error_catcher():
# --> 862     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     863     if amt is not None and amt != 0 and not data:
#     864         # Platform-specific: Buggy versions of Python.
#     865         # Close the connection when no data is returned
#    (...)
#     870         # not properly close the connection in all cases. There is
#     871         # no harm in redundantly calling close.
#     872         self._fp.close()
#
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:845, in HTTPResponse._fp_read(self, amt, read1)
#     842     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     843 else:
#     844     # StringIO doesn't like amt=None
# --> 845     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/nmaps2/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from neuromaps.datasets import fetch_annotation
from neuromaps import transforms
import nibabel as nib

"""
labels_lh, ctab_lh, names_rh = nib.freesurfer.read_annot(rannot)
print(labels_lh.shape)
print(len(names_rh))

rfake = np.random.random(36)
#vol_data[:, 0],
"""
fake = np.random.rand(72)

lannot = '/Users/pecsok/Desktop/lh.aparc.DKTatlas.annot'
rannot = '/Users/pecsok/Desktop/rh.aparc.DKTatlas.annot'

if scale == 'desikan_killiany':    
    brain = plotting.plot_fsaverage(data=fake, 
                                    lhannot = lannot,
                                    rhannot = rannot,
                                    colormap='plasma',
                                    views=['lat', 'med'],
                                    data_kws={'representation': "wireframe"})
    #brain.save_image(figpath + folder + '/surface_receptor_'+receptor_names[k]+'.png')
# Out:
# qt.qpa.window: <QNSWindow: 0x40e8d4530; contentView=<QNSView: 0x40e8d4130; QCocoaWindow(0x6000006c8420, window=QWidgetWindow(0x6000095aafa0, name="QMainWindowClassWindow"))>> has active key-value observers (KVO)! These will stop working now that the window is recreated, and will result in exceptions when the observers are removed. Break in QCocoaWindow::recreateWindowIfNeeded to debug.
# qt.qpa.window: <QNSWindow: 0x3ded27e80; contentView=<QNSView: 0x3ded27a80; QCocoaWindow(0x60000069b2e0, window=QWidgetWindow(0x600005bfa400, name="QMainWindowClassWindow"))>> has active key-value observers (KVO)! These will stop working now that the window is recreated, and will result in exceptions when the observers are removed. Break in QCocoaWindow::recreateWindowIfNeeded to debug.
# qt.qpa.window: <QNSWindow: 0x3ded93fb0; contentView=<QNSView: 0x3ded93bb0; QCocoaWindow(0x6000006d5080, window=QWidgetWindow(0x6000095e6220, name="QMainWindowClassWindow"))>> has active key-value observers (KVO)! These will stop working now that the window is recreated, and will result in exceptions when the observers are removed. Break in QCocoaWindow::recreateWindowIfNeeded to debug.
# qt.qpa.window: <QNSWindow: 0x4333abed0; contentView=<QNSView: 0x4333abad0; QCocoaWindow(0x6000006c2cb0, window=QWidgetWindow(0x6000095f9c20, name="QMainWindowClassWindow"))>> has active key-value observers (KVO)! These will stop working now that the window is recreated, and will result in exceptions when the observers are removed. Break in QCocoaWindow::recreateWindowIfNeeded to debug.
# qt.qpa.window: <QNSWindow: 0x443534460; contentView=<QNSView: 0x443533f90; QCocoaWindow(0x6000006cac00, window=QWidgetWindow(0x6000095c1380, name="QWidgetClassWindow"))>> has active key-value observers (KVO)! These will stop working now that the window is recreated, and will result in exceptions when the observers are removed. Break in QCocoaWindow::recreateWindowIfNeeded to debug.
# qt.qpa.window: <QNSWindow: 0x3ded83e50; contentView=<QNSView: 0x3ded83980; QCocoaWindow(0x6000006d4b00, window=QWidgetWindow(0x6000095dfd80, name="QWidgetClassWindow"))>> has active key-value observers (KVO)! These will stop working now that the window is recreated, and will result in exceptions when the observers are removed. Break in QCocoaWindow::recreateWindowIfNeeded to debug.
# qt.qpa.window: <QNSWindow: 0x3dededed0; contentView=<QNSView: 0x3dededa00; QCocoaWindow(0x6000006d77b0, window=QWidgetWindow(0x6000095e84e0, name="QWidgetClassWindow"))>> has active key-value observers (KVO)! These will stop working now that the window is recreated, and will result in exceptions when the observers are removed. Break in QCocoaWindow::recreateWindowIfNeeded to debug.
# qt.qpa.window: <QNSWindow: 0x443609f60; contentView=<QNSView: 0x443609a90; QCocoaWindow(0x6000006d1a20, window=QWidgetWindow(0x600009417960, name="QWidgetClassWindow"))>> has active key-value observers (KVO)! These will stop working now that the window is recreated, and will result in exceptions when the observers are removed. Break in QCocoaWindow::recreateWindowIfNeeded to debug.
# qt.qpa.window: <QNSWindow: 0x44360faf0; contentView=<QNSView: 0x44360bce0; QCocoaWindow(0x6000006d1c30, window=QWidgetWindow(0x600009410720, name="QWidgetClassWindow"))>> has active key-value observers (KVO)! These will stop working now that the window is recreated, and will result in exceptions when the observers are removed. Break in QCocoaWindow::recreateWindowIfNeeded to debug.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 19
#      16 rannot = '/Users/pecsok/Desktop/rh.aparc.DKTatlas.annot'
#      18 if scale == 'desikan_killiany':
# ---> 19     brain = plotting.plot_fsaverage(data=fake,
#      20                                     lhannot = lannot,
#      21                                     rhannot = rannot,
#      22                                     colormap='plasma',
#      23                                     views=['lat', 'med'],
#      24                                     data_kws={'representation': "wireframe"})
#      25     #brain.save_image(figpath + folder + '/surface_receptor_'+receptor_names[k]+'.png')
#
# File ~/.local/lib/python3.11/site-packages/netneurotools/plotting.py:570, in plot_fsaverage(data, lhannot, rhannot, order, mask, noplot, subject_id, subjects_dir, vmin, vmax, **kwargs)
#     566         vtx[maskdata[labels] > 0] = np.nan
#     568     vtx_data.append(vtx)
# --> 570 brain = plot_fsvertex(np.hstack(vtx_data), order='lr', mask=None,
#     571                       subject_id=subject_id, subjects_dir=subjects_dir,
#     572                       vmin=vmin, vmax=vmax, **kwargs)
#     574 return brain
#
# File ~/.local/lib/python3.11/site-packages/netneurotools/plotting.py:673, in plot_fsvertex(data, order, surf, views, vmin, vmax, center, mask, colormap, colorbar, alpha, label_fmt, num_labels, size_per_view, subject_id, subjects_dir, data_kws, **kwargs)
#     669 brain = Brain(subject_id=subject_id, hemi='split', surf=surf,
#     670               subjects_dir=subjects_dir, views=views, **brain_kws)
#     672 hemis = ('lh', 'rh') if order == 'lr' else ('rh', 'lh')
# --> 673 for n, (hemi, vtx_data) in enumerate(zip(hemis, np.split(data, 2))):
#     674     # let's mask data, if necessary
#     675     if mask is not None:
#     676         maskdata = np.asarray(np.split(mask, 2)[n], dtype=bool)
#
# File ~/.local/lib/python3.11/site-packages/numpy/lib/shape_base.py:864, in split(ary, indices_or_sections, axis)
#     862     N = ary.shape[axis]
#     863     if N % sections:
# --> 864         raise ValueError(
#     865             'array split does not result in an equal division') from None
#     866 return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division

# %%
fsavg = transforms.mni152_to_fsaverage(desikan, '164k')
lhannot = fsavg[0]
ldata_array = lhannot.darrays[0].data
lunique_labels = np.unique(ldata_array)
llabels = [f'label_{int(label)}' for label in lunique_labels]
# Create a colormap with random RGB values for each unique label (or define your own)
lcolormap = np.zeros((len(lunique_labels) + 1, 4), dtype=np.int32)  # +1 for background
for i, label in enumerate(lunique_labels):
    colormap[i + 1] = [i * 40 % 255, i * 80 % 255, i * 120 % 255, 255]  # RGB + alpha

nib.freesurfer.write_annot(
    '/Users/pecsok/Desktop/atl-desikan_space-fsaverage_res-112_hemi-L_deterministic.annot',
    labels=ldata_array.astype(int),  # Label array from Gifti data
    ctab=lcolormap,                  # Color table
    names=llabels                    # List of region names
)  

# Right hemisphere
rhannot = fsavg[1]
rdata_array = rhannot.darrays[0].data
runique_labels = np.unique(rdata_array)
rlabels = [f'label_{int(label)}' for label in runique_labels]
# Create a colormap with random RGB values for each unique label (or define your own)
rcolormap = np.zeros((len(runique_labels) + 1, 4), dtype=np.int32)  # +1 for background
for i, label in enumerate(runique_labels):
    colormap[i + 1] = [i * 40 % 255, i * 80 % 255, i * 120 % 255, 255]  # RGB + alpha

nib.freesurfer.write_annot(
    '/Users/pecsok/Desktop/atl-desikan_space-fsaverage_res-112_hemi-R_deterministic.annot',
    labels=rdata_array.astype(int),  # Label array from Gifti data
    ctab=rcolormap,                  # Color table
    names=rlabels                    # List of region names
)
"""

# %%
info = pd.read_csv(cammoun['info'], sep=',')
info = info[info['scale']== 'scale500']
hemisphere = info['hemisphere'].values
labels = info['label'].values + hemisphere
