# %% [markdown]
# ## Pipeline Script
#
#
# Inputs: Group CEST and nmap data output from pyGluCEST as well as demographic data from _________.
# Outputs: Compiled dataframes with GluCEST and nmap data. Trimmed based on number of people with sufficient data.
#
#     Trimmed subject-wise dfs: e.g., cestmat (outpath + 'trimmed_cestmat' + dataset + atlas + '.csv')
#     Long form dfs: e.g., long_df (outpath + 'longform_grpdf' + dataset + '_' + atlas + '.csv')
#          Also have version with standard nmap values
#     Mean dfs: e.g., grouped_df (outpath + 'means_' + dataset + '_' + atlas + '.csv')

# %% [markdown]
# ### Import Packages

# %%
import os
import glob
import numpy as np
import pandas as pd
#import network_fcon as fc
import scipy as sp
from scipy.stats import pearsonr
from scipy.stats import linregress
import seaborn as sns
import matplotlib.pyplot as plt
import re
from nilearn.datasets import fetch_atlas_schaefer_2018

# %% [markdown]
# ### Define paths and variables

# %%
# Set variables
dataset = 'longglucest_outputmeasures2'
atlas = 'Schaefer2018_1000Parcels_17Networks'
atlas_name = 'schaefer'
if atlas_name == 'schaefer':
    scale='scale1000_17'
    schaefer = fetch_atlas_schaefer_2018(n_rois=1000, yeo_networks=17) # This is sklearn.utils._bunch.Bunch. Other altases in this format? *Ask Golia
    nnodes = len(schaefer['labels'])
    

receptors = ["5HT1a", "5HT1b", "5HT2a", "5HT4", "5HT6", "5HTT", "A4B2",
             "CB1", "D1", "D2", "DAT", "GABAa", "H3", "M1", "mGluR5",
             "MOR", "NET", "NMDA", "VAChT"]
features = ['abaPC1','CBF','CBV','CThick','Glucose','O2met','SAaxis']

nmaps = ["NMDA", "mGluR5", "GABA"]
maps = ["cest", "NMDA", "mGluR5", "GABA"]


# Set paths
inpath = "/Users/pecsok/Desktop/ImageData/PMACS_remote/data/nmaps/" + dataset
outpath = "/Users/pecsok/Desktop/ImageData/PMACS_remote/data/nmaps/analyses/" + atlas
outpath2 = "/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/results/" 

# Read in data
cestmat = pd.read_csv(inpath + "/all_subs_GluCEST_" + atlas + "_UNI.csv", sep=',')
cestmat.set_index('Subject', inplace = True)

# Load in standardized nmap data
receptor_df = pd.read_csv("/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/results/receptor_data_all_scale1000_17.csv", sep=',')
feature_df = pd.read_csv("/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/results/feature_data_all_scale1000_17.csv", sep=',')

# %%
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#print(grp_df)

# %% [markdown]
# ## Trim Data

# %%
# ID parcels with < 20 voxels* 
for i, col in enumerate(cestmat.columns):
    if 'NZcount' in col:
        # Set mean col to nan
        mean_col = cestmat.columns[i - 1]
        sigma_col = cestmat.columns[i + 1]
        cestmat[mean_col] = np.where(cestmat[col] < 20, np.nan, cestmat[mean_col])
        cestmat[sigma_col] = np.where(cestmat[col] < 20, np.nan, cestmat[sigma_col])
        cestmat[col] = np.where(cestmat[col] < 20, np.nan, cestmat[col])       
columns = cestmat.columns[cestmat.notnull().sum() > len(cestmat)*.75]
print(cestmat.shape)

# Trim cest df based on column filter
cestmat= cestmat[columns]
print(cestmat.shape)

# Remove subjects missing >65% of remaining GluCEST parcels
sparse_subjs = cestmat[cestmat.isna().sum(axis=1) > cestmat.shape[1] * 0.65].index
cestmat = cestmat.drop(index=sparse_subjs)
print(cestmat.shape)

# Save trimmed dfs
cestmat.to_csv(outpath + '/trimmed_cestmat' + dataset + atlas + scale + '.csv', index=True)
cestmat.to_csv(outpath2 + '/trimmed_cestmat' + dataset + atlas + scale + '.csv', index=True)
# Out:
# (176, 830)
# (176, 203)
# (172, 203)

# %%
cestmat
# Out:
#               Unnamed: 0    group  17Networks_RH_VisCent_Striate_2 NZMean  \
# Subject
# 100522_12003           0    TD/NC                                     NaN
# 100522_12371           1    TD/NC                                     NaN
# 100522_12783           2    TD/NC                                     NaN
# 102041_12037           3  PRO/CHR                                6.896060
# 102041_12500           4  PRO/CHR                                9.101267
# ...                  ...      ...                                     ...
# 96902_11903          171    TD/NC                               10.768049
# 96902_12440          172    TD/NC                                     NaN
# 96902_12788          173    TD/NC                                     NaN
# 98370_12558          174    TD/NC                                8.194758
# 98370_12952          175    TD/NC                                7.623180
#
#               17Networks_RH_VisCent_Striate_2 NZcount  \
# Subject
# 100522_12003                                      NaN
# 100522_12371                                      NaN
# 100522_12783                                      NaN
# 102041_12037                                     46.0
# 102041_12500                                     56.0
# ...                                               ...
# 96902_11903                                      32.0
# 96902_12440                                       NaN
# 96902_12788                                       NaN
# 98370_12558                                      40.0
# 98370_12952                                      60.0
#
#               17Networks_RH_VisCent_Striate_2 NZSigma  \
# Subject
# 100522_12003                                      NaN
# 100522_12371                                      NaN
# 100522_12783                                      NaN
# 102041_12037                                 2.100414
# 102041_12500                                 1.292699
# ...                                               ...
# 96902_11903                                  1.255749
# 96902_12440                                       NaN
# 96902_12788                                       NaN
# 98370_12558                                  1.616630
# 98370_12952                                  1.505168
#
#               17Networks_RH_VisCent_ExStr_14 NZMean  \
# Subject
# 100522_12003                              11.568608
# 100522_12371                                    NaN
# 100522_12783                                    NaN
# 102041_12037                               7.324809
# 102041_12500                              10.588638
# ...                                             ...
# 96902_11903                               11.407769
# 96902_12440                                     NaN
# 96902_12788                                     NaN
# 98370_12558                                7.327654
# 98370_12952                                6.850946
#
#               17Networks_RH_VisCent_ExStr_14 NZcount  \
# Subject
# 100522_12003                                    30.0
# 100522_12371                                     NaN
# 100522_12783                                     NaN
# 102041_12037                                    91.0
# 102041_12500                                   104.0
# ...                                              ...
# 96902_11903                                     27.0
# 96902_12440                                      NaN
# 96902_12788                                      NaN
# 98370_12558                                     51.0
# 98370_12952                                     76.0
#
#               17Networks_RH_VisCent_ExStr_14 NZSigma  \
# Subject
# 100522_12003                                2.090549
# 100522_12371                                     NaN
# 100522_12783                                     NaN
# 102041_12037                                3.142994
# 102041_12500                                3.798515
# ...                                              ...
# 96902_11903                                 1.396833
# 96902_12440                                      NaN
# 96902_12788                                      NaN
# 98370_12558                                 2.525033
# 98370_12952                                 2.230569
#
#               17Networks_RH_VisCent_ExStr_17 NZMean  \
# Subject
# 100522_12003                              11.563977
# 100522_12371                              12.899275
# 100522_12783                              12.170283
# 102041_12037                               6.183180
# 102041_12500                               9.020026
# ...                                             ...
# 96902_11903                               10.797512
# 96902_12440                                8.112674
# 96902_12788                               11.959593
# 98370_12558                                7.128996
# 98370_12952                                7.058454
#
#               17Networks_RH_VisCent_ExStr_17 NZcount  ...  \
# Subject                                               ...
# 100522_12003                                    91.0  ...
# 100522_12371                                    79.0  ...
# 100522_12783                                    92.0  ...
# 102041_12037                                    59.0  ...
# 102041_12500                                    59.0  ...
# ...                                              ...  ...
# 96902_11903                                     88.0  ...
# 96902_12440                                     57.0  ...
# 96902_12788                                     62.0  ...
# 98370_12558                                     72.0  ...
# 98370_12952                                     50.0  ...
#
#               17Networks_RH_ContC_pCun_10 NZSigma  \
# Subject
# 100522_12003                                  NaN
# 100522_12371                                  NaN
# 100522_12783                                  NaN
# 102041_12037                                  NaN
# 102041_12500                             2.031342
# ...                                           ...
# 96902_11903                              1.151236
# 96902_12440                                   NaN
# 96902_12788                                   NaN
# 98370_12558                              1.552773
# 98370_12952                              1.873792
#
#               17Networks_RH_ContC_pCun_11 NZMean  \
# Subject
# 100522_12003                                 NaN
# 100522_12371                                 NaN
# 100522_12783                                 NaN
# 102041_12037                            5.825535
# 102041_12500                            8.001007
# ...                                          ...
# 96902_11903                             9.823335
# 96902_12440                                  NaN
# 96902_12788                                  NaN
# 98370_12558                             7.736004
# 98370_12952                             7.013587
#
#               17Networks_RH_ContC_pCun_11 NZcount  \
# Subject
# 100522_12003                                  NaN
# 100522_12371                                  NaN
# 100522_12783                                  NaN
# 102041_12037                                 23.0
# 102041_12500                                 28.0
# ...                                           ...
# 96902_11903                                  62.0
# 96902_12440                                   NaN
# 96902_12788                                   NaN
# 98370_12558                                  43.0
# 98370_12952                                  47.0
#
#               17Networks_RH_ContC_pCun_11 NZSigma  \
# Subject
# 100522_12003                                  NaN
# 100522_12371                                  NaN
# 100522_12783                                  NaN
# 102041_12037                             2.046068
# 102041_12500                             1.791779
# ...                                           ...
# 96902_11903                              1.501530
# 96902_12440                                   NaN
# 96902_12788                                   NaN
# 98370_12558                              1.536167
# 98370_12952                              1.426732
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZMean  \
# Subject
# 100522_12003                                      NaN
# 100522_12371                                      NaN
# 100522_12783                                      NaN
# 102041_12037                                 9.435372
# 102041_12500                                 7.621892
# ...                                               ...
# 96902_11903                                  9.892211
# 96902_12440                                       NaN
# 96902_12788                                       NaN
# 98370_12558                                  7.794032
# 98370_12952                                  7.244376
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZcount  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                      28.0
# 102041_12500                                      29.0
# ...                                                ...
# 96902_11903                                       38.0
# 96902_12440                                        NaN
# 96902_12788                                        NaN
# 98370_12558                                       46.0
# 98370_12952                                       43.0
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZSigma  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  3.355391
# 102041_12500                                  1.634854
# ...                                                ...
# 96902_11903                                   1.099129
# 96902_12440                                        NaN
# 96902_12788                                        NaN
# 98370_12558                                   1.817249
# 98370_12952                                   1.825592
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZMean  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  7.549210
# 102041_12500                                  8.149293
# ...                                                ...
# 96902_11903                                   8.674353
# 96902_12440                                        NaN
# 96902_12788                                        NaN
# 98370_12558                                   8.809414
# 98370_12952                                   7.371335
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZcount  \
# Subject
# 100522_12003                                        NaN
# 100522_12371                                        NaN
# 100522_12783                                        NaN
# 102041_12037                                       23.0
# 102041_12500                                       23.0
# ...                                                 ...
# 96902_11903                                        37.0
# 96902_12440                                         NaN
# 96902_12788                                         NaN
# 98370_12558                                        35.0
# 98370_12952                                        37.0
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZSigma
# Subject
# 100522_12003                                        NaN
# 100522_12371                                        NaN
# 100522_12783                                        NaN
# 102041_12037                                   2.533496
# 102041_12500                                   1.433568
# ...                                                 ...
# 96902_11903                                    1.250330
# 96902_12440                                         NaN
# 96902_12788                                         NaN
# 98370_12558                                    1.044155
# 98370_12952                                    1.705025
#
# [172 rows x 203 columns]

# %%
feature_df
# Out:
#                               Parcel    abaPC1       CBF       CBV    CThick  \
# 0    17Networks_LH_VisCent_Striate_1 -1.017269  1.080034 -0.309541 -0.344899
# 1    17Networks_LH_VisCent_Striate_2 -1.528741  0.230634 -0.996347 -0.077911
# 2    17Networks_LH_VisCent_Striate_3 -1.335038  2.179686  2.491076  0.130418
# 3    17Networks_LH_VisCent_Striate_4 -2.391152 -1.332028 -1.267029 -0.397107
# 4      17Networks_LH_VisCent_ExStr_1  0.844841 -0.821664 -1.020337 -0.943399
# ..                               ...       ...       ...       ...       ...
# 995         17Networks_RH_TempPar_18  0.252809 -0.296236  0.183355  0.039980
# 996         17Networks_RH_TempPar_19 -0.144144  0.320504  0.160905  0.726872
# 997         17Networks_RH_TempPar_20  0.685681 -0.125140  0.285438  0.288808
# 998         17Networks_RH_TempPar_21  0.306854 -0.205778  0.195602  0.987100
# 999         17Networks_RH_TempPar_22  0.555347  0.287524  1.018415  0.141915
#
#       Glucose     O2met    SAaxis
# 0   -2.199974 -2.012666 -0.195458
# 1   -2.273773 -1.616657 -0.030261
# 2   -2.028452  0.989703  0.319988
# 3   -2.150991 -1.594636 -0.168181
# 4   -0.796223 -0.077485 -0.602312
# ..        ...       ...       ...
# 995  0.995451  0.392090  0.046803
# 996  1.137494 -0.121955 -0.166595
# 997  0.805814  0.870236 -0.191560
# 998  1.273230  0.505388 -0.241407
# 999  1.394277  0.893092 -0.162679
#
# [1000 rows x 8 columns]

# %%
receptor_df
# Out:
#                                                           Parcel      5HT1a  \
# Parcel
# 17Networks_LH_VisCent_Striate_1  17Networks_LH_VisCent_Striate_1  18.948129
# 17Networks_LH_VisCent_Striate_2  17Networks_LH_VisCent_Striate_2  14.188564
# 17Networks_LH_VisCent_Striate_3  17Networks_LH_VisCent_Striate_3  15.991089
# 17Networks_LH_VisCent_Striate_4  17Networks_LH_VisCent_Striate_4   6.163279
# 17Networks_LH_VisCent_ExStr_1      17Networks_LH_VisCent_ExStr_1  36.276247
# ...                                                          ...        ...
# 17Networks_RH_TempPar_18                17Networks_RH_TempPar_18  30.767017
# 17Networks_RH_TempPar_19                17Networks_RH_TempPar_19  27.073119
# 17Networks_RH_TempPar_20                17Networks_RH_TempPar_20  34.795170
# 17Networks_RH_TempPar_21                17Networks_RH_TempPar_21  31.269943
# 17Networks_RH_TempPar_22                17Networks_RH_TempPar_22  33.582324
#
#                                     5HT1b      5HT2a      5HT4      5HT6  \
# Parcel
# 17Networks_LH_VisCent_Striate_1  0.041845  48.899766  1.214659  0.076800
# 17Networks_LH_VisCent_Striate_2 -0.686076  51.189834  1.184958  0.136049
# 17Networks_LH_VisCent_Striate_3  2.412334  52.976763  1.283687  0.525998
# 17Networks_LH_VisCent_Striate_4 -1.283465  48.451955  1.234372  0.139344
# 17Networks_LH_VisCent_ExStr_1   -0.970097  43.766169  1.779596  0.366331
# ...                                   ...        ...       ...       ...
# 17Networks_RH_TempPar_18         0.062079  52.201041  2.500652  0.436586
# 17Networks_RH_TempPar_19         0.201264  58.092809  2.557817  0.359678
# 17Networks_RH_TempPar_20         0.181614  54.335341  2.424333  0.508124
# 17Networks_RH_TempPar_21         0.094104  60.324896  2.612443  0.453537
# 17Networks_RH_TempPar_22         0.833592  53.075380  2.661159  0.511543
#
#                                      5HTT       A4B2       CB1         D1  \
# Parcel
# 17Networks_LH_VisCent_Striate_1  4.452689   5.702382  1.120613  10.222895
# 17Networks_LH_VisCent_Striate_2  4.699549   6.015368  1.171355   9.386907
# 17Networks_LH_VisCent_Striate_3  5.222937   8.935845  1.115665  13.823058
# 17Networks_LH_VisCent_Striate_4  4.493451   6.665540  1.171664   4.613154
# 17Networks_LH_VisCent_ExStr_1    3.844715  10.412034  1.351787  16.448932
# ...                                   ...        ...       ...        ...
# 17Networks_RH_TempPar_18         4.814709  10.125429  1.191691  19.034882
# 17Networks_RH_TempPar_19         4.495821   8.995112  1.342542  12.808795
# 17Networks_RH_TempPar_20         4.458515  10.177820  1.266869  17.551809
# 17Networks_RH_TempPar_21         4.384027  10.249098  1.258140  17.350270
# 17Networks_RH_TempPar_22         4.501673  10.470014  1.314911  17.938921
#
#                                        D2        DAT       GABAa         H3  \
# Parcel
# 17Networks_LH_VisCent_Striate_1 -1.793413  27.112566  801.482003  12.104925
# 17Networks_LH_VisCent_Striate_2 -1.725353  25.816654  876.656020  13.585886
# 17Networks_LH_VisCent_Striate_3 -1.079382  27.518347  973.196315  16.292319
# 17Networks_LH_VisCent_Striate_4 -1.734788  24.172900  720.693036  13.789880
# 17Networks_LH_VisCent_ExStr_1    0.268522  30.359035  821.139673  16.388692
# ...                                   ...        ...         ...        ...
# 17Networks_RH_TempPar_18         0.148707  30.644053  782.871657  12.937686
# 17Networks_RH_TempPar_19         0.217057  26.675196  729.726225  18.514514
# 17Networks_RH_TempPar_20         0.635338  30.020101  762.064750  15.281439
# 17Networks_RH_TempPar_21         0.371140  29.822684  806.598835  14.278674
# 17Networks_RH_TempPar_22         0.717365  29.708248  807.334648  16.835478
#
#                                        M1    mGluR5        MOR       NET  \
# Parcel
# 17Networks_LH_VisCent_Striate_1  2.123639 -1.676590   0.000000 -0.165843
# 17Networks_LH_VisCent_Striate_2  2.649931 -1.582004   0.000000 -0.146195
# 17Networks_LH_VisCent_Striate_3  4.259038 -0.612121   0.000000  0.034422
# 17Networks_LH_VisCent_Striate_4  3.392128 -2.019832   0.000000 -0.090363
# 17Networks_LH_VisCent_ExStr_1    2.804235 -0.341650  19.869329  0.012567
# ...                                   ...       ...        ...       ...
# 17Networks_RH_TempPar_18         3.255362  0.748027  21.933858  0.055272
# 17Networks_RH_TempPar_19         4.238721  0.810461  19.715440  0.074454
# 17Networks_RH_TempPar_20         4.008876  0.746511  22.437446  0.035453
# 17Networks_RH_TempPar_21         3.641749  1.057345  23.829075  0.042169
# 17Networks_RH_TempPar_22         4.152305  1.022109  22.469481  0.099152
#
#                                      NMDA     VAChT
# Parcel
# 17Networks_LH_VisCent_Striate_1  6.506956 -0.284921
# 17Networks_LH_VisCent_Striate_2  5.825221 -0.280327
# 17Networks_LH_VisCent_Striate_3  7.150124 -0.090520
# 17Networks_LH_VisCent_Striate_4  5.112683 -0.333713
# 17Networks_LH_VisCent_ExStr_1    7.171719  0.062423
# ...                                   ...       ...
# 17Networks_RH_TempPar_18         7.154420  0.034462
# 17Networks_RH_TempPar_19         6.208405 -0.014531
# 17Networks_RH_TempPar_20         7.109887  0.020519
# 17Networks_RH_TempPar_21         7.077804  0.007031
# 17Networks_RH_TempPar_22         6.504531  0.100859
#
# [1000 rows x 20 columns]

# %% [markdown]
# # Add neuromaps data standard nmaps

# %%
# Import and add parcel labels to standard receptor_df
"""
schaefer = fetch_atlas_schaefer_2018(n_rois=1000, yeo_networks=17)
labels = schaefer.labels
labels = [label.decode('utf-8') for label in labels]
receptor_df.index = labels
receptor_df.index.name = 'Parcel'
feature_df.index = labels
feature_df.index.name = 'Parcel'
"""

# %% [markdown]
# ### Make classic grp_df

# %%
grp_df_std
# Out:
#               Unnamed: 0    group  17Networks_RH_VisCent_Striate_2 NZMean  \
# 100522_12003         0.0    TD/NC                                     NaN
# 100522_12371         1.0    TD/NC                                     NaN
# 100522_12783         2.0    TD/NC                                     NaN
# 102041_12037         3.0  PRO/CHR                                6.896060
# 102041_12500         4.0  PRO/CHR                                9.101267
# ...                  ...      ...                                     ...
# 167                  NaN      NaN                                     NaN
# 168                  NaN      NaN                                     NaN
# 169                  NaN      NaN                                     NaN
# 170                  NaN      NaN                                     NaN
# 171                  NaN      NaN                                     NaN
#
#               17Networks_RH_VisCent_Striate_2 NZcount  \
# 100522_12003                                      NaN
# 100522_12371                                      NaN
# 100522_12783                                      NaN
# 102041_12037                                     46.0
# 102041_12500                                     56.0
# ...                                               ...
# 167                                               NaN
# 168                                               NaN
# 169                                               NaN
# 170                                               NaN
# 171                                               NaN
#
#               17Networks_RH_VisCent_Striate_2 NZSigma  \
# 100522_12003                                      NaN
# 100522_12371                                      NaN
# 100522_12783                                      NaN
# 102041_12037                                 2.100414
# 102041_12500                                 1.292699
# ...                                               ...
# 167                                               NaN
# 168                                               NaN
# 169                                               NaN
# 170                                               NaN
# 171                                               NaN
#
#               17Networks_RH_VisCent_ExStr_14 NZMean  \
# 100522_12003                              11.568608
# 100522_12371                                    NaN
# 100522_12783                                    NaN
# 102041_12037                               7.324809
# 102041_12500                              10.588638
# ...                                             ...
# 167                                             NaN
# 168                                             NaN
# 169                                             NaN
# 170                                             NaN
# 171                                             NaN
#
#               17Networks_RH_VisCent_ExStr_14 NZcount  \
# 100522_12003                                    30.0
# 100522_12371                                     NaN
# 100522_12783                                     NaN
# 102041_12037                                    91.0
# 102041_12500                                   104.0
# ...                                              ...
# 167                                              NaN
# 168                                              NaN
# 169                                              NaN
# 170                                              NaN
# 171                                              NaN
#
#               17Networks_RH_VisCent_ExStr_14 NZSigma  \
# 100522_12003                                2.090549
# 100522_12371                                     NaN
# 100522_12783                                     NaN
# 102041_12037                                3.142994
# 102041_12500                                3.798515
# ...                                              ...
# 167                                              NaN
# 168                                              NaN
# 169                                              NaN
# 170                                              NaN
# 171                                              NaN
#
#               17Networks_RH_VisCent_ExStr_17 NZMean  \
# 100522_12003                              11.563977
# 100522_12371                              12.899275
# 100522_12783                              12.170283
# 102041_12037                               6.183180
# 102041_12500                               9.020026
# ...                                             ...
# 167                                             NaN
# 168                                             NaN
# 169                                             NaN
# 170                                             NaN
# 171                                             NaN
#
#               17Networks_RH_VisCent_ExStr_17 NZcount  ...  \
# 100522_12003                                    91.0  ...
# 100522_12371                                    79.0  ...
# 100522_12783                                    92.0  ...
# 102041_12037                                    59.0  ...
# 102041_12500                                    59.0  ...
# ...                                              ...  ...
# 167                                              NaN  ...
# 168                                              NaN  ...
# 169                                              NaN  ...
# 170                                              NaN  ...
# 171                                              NaN  ...
#
#               17Networks_RH_ContC_pCun_10 NZSigma  \
# 100522_12003                                  NaN
# 100522_12371                                  NaN
# 100522_12783                                  NaN
# 102041_12037                                  NaN
# 102041_12500                             2.031342
# ...                                           ...
# 167                                           NaN
# 168                                           NaN
# 169                                           NaN
# 170                                           NaN
# 171                                           NaN
#
#               17Networks_RH_ContC_pCun_11 NZMean  \
# 100522_12003                                 NaN
# 100522_12371                                 NaN
# 100522_12783                                 NaN
# 102041_12037                            5.825535
# 102041_12500                            8.001007
# ...                                          ...
# 167                                          NaN
# 168                                          NaN
# 169                                          NaN
# 170                                          NaN
# 171                                          NaN
#
#               17Networks_RH_ContC_pCun_11 NZcount  \
# 100522_12003                                  NaN
# 100522_12371                                  NaN
# 100522_12783                                  NaN
# 102041_12037                                 23.0
# 102041_12500                                 28.0
# ...                                           ...
# 167                                           NaN
# 168                                           NaN
# 169                                           NaN
# 170                                           NaN
# 171                                           NaN
#
#               17Networks_RH_ContC_pCun_11 NZSigma  \
# 100522_12003                                  NaN
# 100522_12371                                  NaN
# 100522_12783                                  NaN
# 102041_12037                             2.046068
# 102041_12500                             1.791779
# ...                                           ...
# 167                                           NaN
# 168                                           NaN
# 169                                           NaN
# 170                                           NaN
# 171                                           NaN
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZMean  \
# 100522_12003                                      NaN
# 100522_12371                                      NaN
# 100522_12783                                      NaN
# 102041_12037                                 9.435372
# 102041_12500                                 7.621892
# ...                                               ...
# 167                                               NaN
# 168                                               NaN
# 169                                               NaN
# 170                                               NaN
# 171                                               NaN
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZcount  \
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                      28.0
# 102041_12500                                      29.0
# ...                                                ...
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZSigma  \
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  3.355391
# 102041_12500                                  1.634854
# ...                                                ...
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZMean  \
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  7.549210
# 102041_12500                                  8.149293
# ...                                                ...
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZcount  \
# 100522_12003                                        NaN
# 100522_12371                                        NaN
# 100522_12783                                        NaN
# 102041_12037                                       23.0
# 102041_12500                                       23.0
# ...                                                 ...
# 167                                                 NaN
# 168                                                 NaN
# 169                                                 NaN
# 170                                                 NaN
# 171                                                 NaN
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZSigma
# 100522_12003                                        NaN
# 100522_12371                                        NaN
# 100522_12783                                        NaN
# 102041_12037                                   2.533496
# 102041_12500                                   1.433568
# ...                                                 ...
# 167                                                 NaN
# 168                                                 NaN
# 169                                                 NaN
# 170                                                 NaN
# 171                                                 NaN
#
# [344 rows x 203 columns]

# %%
## Edited to loop through all receptors:
"""
receptor_types = receptor_df.columns.tolist()
filtered_receptor_dfs = []

# Loop through each receptor type in the original receptor_df
for receptor in receptor_types:
    # Transpose the receptor map
    receptor_transposed = receptor_df[[receptor]].T

    # Keep only parcels contained in cestmat
    cestmat_regions = [col.replace(' NZMean', '') for col in cestmat.columns if ' NZMean' in col]
    receptor_filtered = receptor_transposed[[col for col in receptor_transposed.columns if col in cestmat_regions]]

    # Rename the columns to include the receptor type prefix
    receptor_filtered.columns = [f"{receptor}_{col}" for col in receptor_filtered.columns]

    # Repeat the filtered data to match the length of cestmat
    receptor_repeated = pd.concat([receptor_filtered] * len(cestmat), ignore_index=True)

    # Append the processed receptor data to the list
    filtered_receptor_dfs.append(receptor_repeated)


# Concatenate all receptor data with cestmat
grp_df_std = pd.concat([cestmat] + filtered_receptor_dfs, axis=1)

# Save the final dataframe
grp_df_std.to_csv(outpath + '/grp_df_std_all_receptors' + dataset + atlas + '.csv', index=True)
grp_df_std.to_csv(outpath2 + '/grp_df_std_all_receptors' + dataset + atlas + '.csv', index=True)


print(grp_df_std.shape)
"""
# Out:
# (344, 203)

# %% [markdown]
# ### Make Longform df

# %%
cestlong
# Out:
#        Subject                                    Parcel   GluCEST
# 0            0    17Networks_RH_VisCent_Striate_2 NZMean       NaN
# 1            1    17Networks_RH_VisCent_Striate_2 NZMean       NaN
# 2            2    17Networks_RH_VisCent_Striate_2 NZMean       NaN
# 3            3    17Networks_RH_VisCent_Striate_2 NZMean  6.896060
# 4            4    17Networks_RH_VisCent_Striate_2 NZMean  9.101267
# ...        ...                                       ...       ...
# 23043      339  17Networks_RH_DefaultA_pCunPCC_12 NZMean       NaN
# 23044      340  17Networks_RH_DefaultA_pCunPCC_12 NZMean       NaN
# 23045      341  17Networks_RH_DefaultA_pCunPCC_12 NZMean       NaN
# 23046      342  17Networks_RH_DefaultA_pCunPCC_12 NZMean       NaN
# 23047      343  17Networks_RH_DefaultA_pCunPCC_12 NZMean       NaN
#
# [23048 rows x 3 columns]

# %%
# Make longform df using standardized nmaps values

#grp_df_std.rename_axis('Subject', inplace=True)
#grp_df_std.reset_index(inplace=True)
# Get list of parcel names
parcels = cestmat.filter(like="NZMean").columns.tolist()

# Melt cestmat to get Glu data in long format
cestlong = grp_df_std.reset_index().melt(id_vars='Subject', value_vars=parcels, 
                                      var_name='Parcel', value_name='GluCEST')

cestlong



"""
# Step 2: Prepare receptor data without subject information
# Loop through receptors to align receptor data with parcels
long_dfs = []
for receptor in receptor_types:  # Loop through receptor names
    receptor_long = grp_df_std[[col for col in grp_df_std.columns if col.startswith(receptor)]]
    
    # Extract the parcel names
    receptor_long.columns = [col.replace(f'{receptor}_', '') for col in receptor_long.columns]
    
    # Transpose receptor data for easier alignment
    receptor_long = receptor_long.T.reset_index()
    receptor_long.columns = ['Parcel', receptor]  # Rename columns for clarity
    
    long_dfs.append(receptor_long)

# Step 3: Merge receptor data into cestlong
for receptor_long in long_dfs:
    cestlong = cestlong.merge(receptor_long, on='Parcel', how='left')

# Final long-form dataframe
print(cestlong)












longdf_cest = long_df[["Subject","Parcel","GluCEST","group","hstatus"]]
longdf_cest["Parcel"] = longdf_cest["Parcel"].str.replace(' NZMean', '', regex=False)

# Convert receptor_df from wide to long format for merging
nmda_long = NMDAmat.reset_index().melt(id_vars='Parcel', var_name='Receptor1', value_name='NMDA_standard')
gaba_long = GABAmat.reset_index().melt(id_vars='Parcel', var_name='Receptor2', value_name='GABA_standard')
mglur5_long = mGluR5mat.reset_index().melt(id_vars='Parcel', var_name='Receptor3', value_name='mGluR5_standard')

# Combine dfs
long_df_std = pd.merge(longdf_cest, nmda_long, on='Parcel', how='left')
long_df_std = pd.merge(long_df_std, gaba_long, on='Parcel', how='left')
long_df_std = pd.merge(long_df_std, mglur5_long, on='Parcel', how='left')
# Remove unnecessary columns
long_df_std = long_df_std.drop(columns=long_df_std.filter(like="Receptor").columns)
#print(long_df_std)

# Save the longform dataframe to a CSV
long_df_std.to_csv(outpath + '/longform_grpdf_std_' + dataset + '_' + atlas + '.csv', index=False)
"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kk/w6xmtt2d55xfbxvb6wcqhq580000gp/T/ipykernel_28840/3893404638.py in ?()
#       5 # Get list of parcel names
#       6 parcels = cestmat.filter(like="NZMean").columns.tolist()
#       7
#       8 # Melt cestmat to get Glu data in long format
# ----> 9 cestlong = grp_df_std.reset_index().melt(id_vars='Subject', value_vars=parcels,
#      10                                       var_name='Parcel', value_name='GluCEST')
#      11
#      12 cestlong
#
# ~/.local/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~/.local/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert Subject, already exists

# %% [markdown]
# ### Make mean df by diagnosis

# %%
# Make mean group dfs by diagnosis
# Standard nmap data
grouped_std = long_df_std.groupby(['Parcel', 'hstatus']).agg(
    GluCEST_avg=('GluCEST', 'mean'),
    NMDA_avg=('NMDA_standard', 'mean'),
    mGluR5_avg=('mGluR5_standard', 'mean'),
    GABA_avg=('GABA_standard', 'mean')
).reset_index()
#print(grouped_std)
grouped_std.to_csv(outpath + '/means_std_' + dataset + '_' + atlas + '.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 3
#       1 # Make mean group dfs by diagnosis
#       2 # Standard nmap data
# ----> 3 grouped_std = long_df_std.groupby(['Parcel', 'hstatus']).agg(
#       4     GluCEST_avg=('GluCEST', 'mean'),
#       5     NMDA_avg=('NMDA_standard', 'mean'),
#       6     mGluR5_avg=('mGluR5_standard', 'mean'),
#       7     GABA_avg=('GABA_standard', 'mean')
#       8 ).reset_index()
#       9 #print(grouped_std)
#      10 grouped_std.to_csv(outpath + '/means_std_' + dataset + '_' + atlas + '.csv', index=False)
#
# NameError: name 'long_df_std' is not defined

# %% [markdown]
# ### Data Imputation

# %%
# Now, for the long_dfs, impute data based on average across participants for that parcel
# Subject-wise data
merged_df = pd.merge(long_df, grouped_df2[['Parcel', 'hstatus', 'GluCEST_avg']], on=['Parcel', 'hstatus'], how='left')
merged_df['GluCEST'] = merged_df['GluCEST'].fillna(merged_df['GluCEST_avg'])
#print(merged_df)
imputed_df = merged_df.drop(columns=['GluCEST_avg'])

# Standard data
# First, rename parcels
long_df_std["Parcel"] = long_df_std["Parcel"].str.replace(' NZMean', '', regex=False)
#print(long_df_std)
merged_df_std = pd.merge(long_df_std, grouped_df[['Parcel', 'hstatus', 'GluCEST_avg']], on=['Parcel', 'hstatus'], how='left')
merged_df_std['GluCEST'] = merged_df_std ['GluCEST'].fillna(merged_df_std ['GluCEST_avg'])
#print(merged_df_std)
imputed_df_std = merged_df_std.drop(columns=['GluCEST_avg'])

imputed_df.to_csv(outpath + '/imputed_long_df_' + dataset + '_' + atlas + '.csv', index=False)
imputed_df_std.to_csv(outpath + '/imputed_long_df_standardnmaps_' + dataset + '_' + atlas + '.csv', index=False)

# %% [markdown]
# ### Normalize GluCEST values

# %%
# Step 1: Select columns that contain 'NZMean'
nzmean_columns = [col for col in cestmat.columns if 'NZMean' in col]
print(nzmean_columns)

# Step 2: Calculate mean and std deviation for each subject (row-wise) across selected columns
cestmat['Subject_Avg_NZMean'] = cestmat[nzmean_columns].mean(axis=1)
cestmat['Subject_Std_NZMean'] = cestmat[nzmean_columns].std(axis=1)
print(cestmat)

# Step 3: Calculate z-scores for all selected columns at once and store them in a new dataframe
zscore_df = (cestmat[nzmean_columns].sub(cestmat['Subject_Avg_NZMean'], axis=0)
             .div(cestmat['Subject_Std_NZMean'], axis=0))

# Rename z-score columns
zscore_df.columns = [col + '_Zscore' for col in zscore_df.columns]
print(zscore_df.size)
print(zscore_df)
# Step 4: Concatenate the z-scores dataframe to the original cestmat dataframe
zcestmat = pd.concat([cestmat['group'], zscore_df], axis=1)

print(zcestmat)
# Out:
# ['17Networks_RH_VisCent_Striate_2 NZMean', '17Networks_RH_VisCent_ExStr_14 NZMean', '17Networks_RH_VisCent_ExStr_17 NZMean', '17Networks_RH_VisPeri_StriCal_3 NZMean', '17Networks_RH_VisPeri_StriCal_5 NZMean', '17Networks_RH_VisPeri_ExStrInf_7 NZMean', '17Networks_RH_VisPeri_ExStrSup_3 NZMean', '17Networks_RH_SomMotA_6 NZMean', '17Networks_RH_SomMotA_12 NZMean', '17Networks_RH_SomMotA_22 NZMean', '17Networks_RH_SalVentAttnA_ParMed_8 NZMean', '17Networks_RH_SalVentAttnA_FrMed_1 NZMean', '17Networks_RH_SalVentAttnA_FrMed_2 NZMean', '17Networks_RH_SalVentAttnA_FrMed_3 NZMean', '17Networks_RH_SalVentAttnA_FrMed_4 NZMean', '17Networks_RH_SalVentAttnA_FrMed_5 NZMean', '17Networks_RH_SalVentAttnA_FrMed_6 NZMean', '17Networks_RH_SalVentAttnA_FrMed_7 NZMean', '17Networks_RH_SalVentAttnA_FrMed_8 NZMean', '17Networks_RH_SalVentAttnB_PFCmp_1 NZMean', '17Networks_RH_SalVentAttnB_PFCmp_2 NZMean', '17Networks_RH_SalVentAttnB_PFCmp_5 NZMean', '17Networks_RH_SalVentAttnB_Cinga_1 NZMean', '17Networks_RH_LimbicB_OFC_10 NZMean', '17Networks_RH_LimbicB_OFC_12 NZMean', '17Networks_RH_LimbicB_OFC_14 NZMean', '17Networks_RH_LimbicB_OFC_15 NZMean', '17Networks_RH_ContA_Cingm_1 NZMean', '17Networks_RH_ContA_Cingm_2 NZMean', '17Networks_RH_ContB_PFCmp_1 NZMean', '17Networks_RH_ContB_PFCmp_2 NZMean', '17Networks_RH_ContB_PFCmp_3 NZMean', '17Networks_RH_ContC_pCun_3 NZMean', '17Networks_RH_ContC_pCun_5 NZMean', '17Networks_RH_ContC_pCun_6 NZMean', '17Networks_RH_ContC_Cingp_3 NZMean', '17Networks_RH_ContC_Cingp_4 NZMean', '17Networks_RH_DefaultA_pCunPCC_2 NZMean', '17Networks_RH_DefaultA_pCunPCC_4 NZMean', '17Networks_RH_DefaultA_pCunPCC_6 NZMean', '17Networks_RH_DefaultA_pCunPCC_7 NZMean', '17Networks_RH_DefaultA_pCunPCC_8 NZMean', '17Networks_RH_DefaultA_pCunPCC_10 NZMean', '17Networks_RH_DefaultA_pCunPCC_11 NZMean', '17Networks_RH_DefaultA_PFCm_1 NZMean', '17Networks_RH_DefaultA_PFCm_2 NZMean', '17Networks_RH_DefaultA_PFCm_4 NZMean', '17Networks_RH_DefaultA_PFCm_7 NZMean', '17Networks_RH_DefaultA_PFCm_8 NZMean', '17Networks_RH_DefaultA_PFCm_9 NZMean', '17Networks_RH_DefaultA_PFCm_10 NZMean', '17Networks_RH_DefaultB_PFCd_2 NZMean', '17Networks_RH_DefaultB_PFCd_4 NZMean', '17Networks_RH_DefaultC_Rsp_3 NZMean', '17Networks_RH_VisCent_ExStr_28 NZMean', '17Networks_RH_VisPeri_ExStrSup_4 NZMean', '17Networks_RH_VisPeri_ExStrSup_7 NZMean', '17Networks_RH_SomMotA_28 NZMean', '17Networks_RH_SomMotA_40 NZMean', '17Networks_RH_DorsAttnB_PostC_14 NZMean', '17Networks_RH_SalVentAttnA_ParMed_10 NZMean', '17Networks_RH_ContC_pCun_8 NZMean', '17Networks_RH_ContC_pCun_9 NZMean', '17Networks_RH_ContC_pCun_10 NZMean', '17Networks_RH_ContC_pCun_11 NZMean', '17Networks_RH_DefaultA_pCunPCC_5 NZMean', '17Networks_RH_DefaultA_pCunPCC_12 NZMean', 'Subject_Avg_NZMean', 'Subject_Std_NZMean']
#               Unnamed: 0    group  17Networks_RH_VisCent_Striate_2 NZMean  \
# Subject
# 100522_12003           0    TD/NC                                     NaN
# 100522_12371           1    TD/NC                                     NaN
# 100522_12783           2    TD/NC                                     NaN
# 102041_12037           3  PRO/CHR                                6.896060
# 102041_12500           4  PRO/CHR                                9.101267
# ...                  ...      ...                                     ...
# 96902_11903          171    TD/NC                               10.768049
# 96902_12440          172    TD/NC                                     NaN
# 96902_12788          173    TD/NC                                     NaN
# 98370_12558          174    TD/NC                                8.194758
# 98370_12952          175    TD/NC                                7.623180
#
#               17Networks_RH_VisCent_Striate_2 NZcount  \
# Subject
# 100522_12003                                      NaN
# 100522_12371                                      NaN
# 100522_12783                                      NaN
# 102041_12037                                     46.0
# 102041_12500                                     56.0
# ...                                               ...
# 96902_11903                                      32.0
# 96902_12440                                       NaN
# 96902_12788                                       NaN
# 98370_12558                                      40.0
# 98370_12952                                      60.0
#
#               17Networks_RH_VisCent_Striate_2 NZSigma  \
# Subject
# 100522_12003                                      NaN
# 100522_12371                                      NaN
# 100522_12783                                      NaN
# 102041_12037                                 2.100414
# 102041_12500                                 1.292699
# ...                                               ...
# 96902_11903                                  1.255749
# 96902_12440                                       NaN
# 96902_12788                                       NaN
# 98370_12558                                  1.616630
# 98370_12952                                  1.505168
#
#               17Networks_RH_VisCent_ExStr_14 NZMean  \
# Subject
# 100522_12003                              11.568608
# 100522_12371                                    NaN
# 100522_12783                                    NaN
# 102041_12037                               7.324809
# 102041_12500                              10.588638
# ...                                             ...
# 96902_11903                               11.407769
# 96902_12440                                     NaN
# 96902_12788                                     NaN
# 98370_12558                                7.327654
# 98370_12952                                6.850946
#
#               17Networks_RH_VisCent_ExStr_14 NZcount  \
# Subject
# 100522_12003                                    30.0
# 100522_12371                                     NaN
# 100522_12783                                     NaN
# 102041_12037                                    91.0
# 102041_12500                                   104.0
# ...                                              ...
# 96902_11903                                     27.0
# 96902_12440                                      NaN
# 96902_12788                                      NaN
# 98370_12558                                     51.0
# 98370_12952                                     76.0
#
#               17Networks_RH_VisCent_ExStr_14 NZSigma  \
# Subject
# 100522_12003                                2.090549
# 100522_12371                                     NaN
# 100522_12783                                     NaN
# 102041_12037                                3.142994
# 102041_12500                                3.798515
# ...                                              ...
# 96902_11903                                 1.396833
# 96902_12440                                      NaN
# 96902_12788                                      NaN
# 98370_12558                                 2.525033
# 98370_12952                                 2.230569
#
#               17Networks_RH_VisCent_ExStr_17 NZMean  \
# Subject
# 100522_12003                              11.563977
# 100522_12371                              12.899275
# 100522_12783                              12.170283
# 102041_12037                               6.183180
# 102041_12500                               9.020026
# ...                                             ...
# 96902_11903                               10.797512
# 96902_12440                                8.112674
# 96902_12788                               11.959593
# 98370_12558                                7.128996
# 98370_12952                                7.058454
#
#               17Networks_RH_VisCent_ExStr_17 NZcount  ...  \
# Subject                                               ...
# 100522_12003                                    91.0  ...
# 100522_12371                                    79.0  ...
# 100522_12783                                    92.0  ...
# 102041_12037                                    59.0  ...
# 102041_12500                                    59.0  ...
# ...                                              ...  ...
# 96902_11903                                     88.0  ...
# 96902_12440                                     57.0  ...
# 96902_12788                                     62.0  ...
# 98370_12558                                     72.0  ...
# 98370_12952                                     50.0  ...
#
#               17Networks_RH_ContC_pCun_11 NZcount  \
# Subject
# 100522_12003                                  NaN
# 100522_12371                                  NaN
# 100522_12783                                  NaN
# 102041_12037                                 23.0
# 102041_12500                                 28.0
# ...                                           ...
# 96902_11903                                  62.0
# 96902_12440                                   NaN
# 96902_12788                                   NaN
# 98370_12558                                  43.0
# 98370_12952                                  47.0
#
#               17Networks_RH_ContC_pCun_11 NZSigma  \
# Subject
# 100522_12003                                  NaN
# 100522_12371                                  NaN
# 100522_12783                                  NaN
# 102041_12037                             2.046068
# 102041_12500                             1.791779
# ...                                           ...
# 96902_11903                              1.501530
# 96902_12440                                   NaN
# 96902_12788                                   NaN
# 98370_12558                              1.536167
# 98370_12952                              1.426732
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZMean  \
# Subject
# 100522_12003                                      NaN
# 100522_12371                                      NaN
# 100522_12783                                      NaN
# 102041_12037                                 9.435372
# 102041_12500                                 7.621892
# ...                                               ...
# 96902_11903                                  9.892211
# 96902_12440                                       NaN
# 96902_12788                                       NaN
# 98370_12558                                  7.794032
# 98370_12952                                  7.244376
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZcount  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                      28.0
# 102041_12500                                      29.0
# ...                                                ...
# 96902_11903                                       38.0
# 96902_12440                                        NaN
# 96902_12788                                        NaN
# 98370_12558                                       46.0
# 98370_12952                                       43.0
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZSigma  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  3.355391
# 102041_12500                                  1.634854
# ...                                                ...
# 96902_11903                                   1.099129
# 96902_12440                                        NaN
# 96902_12788                                        NaN
# 98370_12558                                   1.817249
# 98370_12952                                   1.825592
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZMean  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  7.549210
# 102041_12500                                  8.149293
# ...                                                ...
# 96902_11903                                   8.674353
# 96902_12440                                        NaN
# 96902_12788                                        NaN
# 98370_12558                                   8.809414
# 98370_12952                                   7.371335
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZcount  \
# Subject
# 100522_12003                                        NaN
# 100522_12371                                        NaN
# 100522_12783                                        NaN
# 102041_12037                                       23.0
# 102041_12500                                       23.0
# ...                                                 ...
# 96902_11903                                        37.0
# 96902_12440                                         NaN
# 96902_12788                                         NaN
# 98370_12558                                        35.0
# 98370_12952                                        37.0
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZSigma  Subject_Avg_NZMean  \
# Subject
# 100522_12003                                        NaN            7.253906
# 100522_12371                                        NaN            7.519954
# 100522_12783                                        NaN            7.431920
# 102041_12037                                   2.533496            7.711760
# 102041_12500                                   1.433568            7.742990
# ...                                                 ...                 ...
# 96902_11903                                    1.250330            8.840435
# 96902_12440                                         NaN            7.758997
# 96902_12788                                         NaN            8.331267
# 98370_12558                                    1.044155            6.972204
# 98370_12952                                    1.705025            6.965157
#
#               Subject_Std_NZMean
# Subject
# 100522_12003            2.091780
# 100522_12371            1.782031
# 100522_12783            1.879264
# 102041_12037            1.416164
# 102041_12500            1.341835
# ...                          ...
# 96902_11903             1.664505
# 96902_12440             1.487162
# 96902_12788             2.239381
# 98370_12558             1.328494
# 98370_12952             1.157385
#
# [172 rows x 205 columns]
# 11868
#               17Networks_RH_VisCent_Striate_2 NZMean_Zscore  \
# Subject
# 100522_12003                                            NaN
# 100522_12371                                            NaN
# 100522_12783                                            NaN
# 102041_12037                                      -0.575993
# 102041_12500                                       1.012253
# ...                                                     ...
# 96902_11903                                        1.158070
# 96902_12440                                             NaN
# 96902_12788                                             NaN
# 98370_12558                                        0.920255
# 98370_12952                                        0.568543
#
#               17Networks_RH_VisCent_ExStr_14 NZMean_Zscore  \
# Subject
# 100522_12003                                      2.062694
# 100522_12371                                           NaN
# 100522_12783                                           NaN
# 102041_12037                                     -0.273239
# 102041_12500                                      2.120714
# ...                                                    ...
# 96902_11903                                       1.542401
# 96902_12440                                            NaN
# 96902_12788                                            NaN
# 98370_12558                                       0.267558
# 98370_12952                                      -0.098681
#
#               17Networks_RH_VisCent_ExStr_17 NZMean_Zscore  \
# Subject
# 100522_12003                                      2.060480
# 100522_12371                                      3.018645
# 100522_12783                                      2.521392
# 102041_12037                                     -1.079381
# 102041_12500                                      0.951709
# ...                                                    ...
# 96902_11903                                       1.175771
# 96902_12440                                       0.237820
# 96902_12788                                       1.620236
# 98370_12558                                       0.118022
# 98370_12952                                       0.080610
#
#               17Networks_RH_VisPeri_StriCal_3 NZMean_Zscore  \
# Subject
# 100522_12003                                       1.429281
# 100522_12371                                       1.712605
# 100522_12783                                       2.095431
# 102041_12037                                       0.054191
# 102041_12500                                       1.400187
# ...                                                     ...
# 96902_11903                                        1.659552
# 96902_12440                                        1.316897
# 96902_12788                                        2.242383
# 98370_12558                                        0.798168
# 98370_12952                                        0.676402
#
#               17Networks_RH_VisPeri_StriCal_5 NZMean_Zscore  \
# Subject
# 100522_12003                                            NaN
# 100522_12371                                            NaN
# 100522_12783                                            NaN
# 102041_12037                                       0.388867
# 102041_12500                                       1.085037
# ...                                                     ...
# 96902_11903                                        0.854854
# 96902_12440                                             NaN
# 96902_12788                                             NaN
# 98370_12558                                        1.685164
# 98370_12952                                        1.214670
#
#               17Networks_RH_VisPeri_ExStrInf_7 NZMean_Zscore  \
# Subject
# 100522_12003                                        2.939193
# 100522_12371                                        1.387559
# 100522_12783                                        2.333393
# 102041_12037                                        0.833441
# 102041_12500                                        1.347762
# ...                                                      ...
# 96902_11903                                         0.798626
# 96902_12440                                         1.118972
# 96902_12788                                              NaN
# 98370_12558                                         2.362108
# 98370_12952                                         0.691403
#
#               17Networks_RH_VisPeri_ExStrSup_3 NZMean_Zscore  \
# Subject
# 100522_12003                                        0.329546
# 100522_12371                                             NaN
# 100522_12783                                             NaN
# 102041_12037                                       -1.146407
# 102041_12500                                        0.932718
# ...                                                      ...
# 96902_11903                                         0.311710
# 96902_12440                                              NaN
# 96902_12788                                         2.467661
# 98370_12558                                         0.131769
# 98370_12952                                         0.175525
#
#               17Networks_RH_SomMotA_6 NZMean_Zscore  \
# Subject
# 100522_12003                                    NaN
# 100522_12371                                    NaN
# 100522_12783                                    NaN
# 102041_12037                               1.321019
# 102041_12500                              -0.727051
# ...                                             ...
# 96902_11903                               -0.091523
# 96902_12440                                     NaN
# 96902_12788                                0.151524
# 98370_12558                                0.351100
# 98370_12952                               -0.301814
#
#               17Networks_RH_SomMotA_12 NZMean_Zscore  \
# Subject
# 100522_12003                                     NaN
# 100522_12371                                0.057445
# 100522_12783                                     NaN
# 102041_12037                                1.290677
# 102041_12500                               -0.620890
# ...                                              ...
# 96902_11903                                 0.258562
# 96902_12440                                 0.497216
# 96902_12788                                 0.318467
# 98370_12558                                 0.346654
# 98370_12952                                -0.415755
#
#               17Networks_RH_SomMotA_22 NZMean_Zscore  ...  \
# Subject                                               ...
# 100522_12003                                     NaN  ...
# 100522_12371                                     NaN  ...
# 100522_12783                                     NaN  ...
# 102041_12037                                0.766950  ...
# 102041_12500                               -0.713168  ...
# ...                                              ...  ...
# 96902_11903                                 0.164720  ...
# 96902_12440                                 0.303225  ...
# 96902_12788                                 0.170085  ...
# 98370_12558                                -0.729627  ...
# 98370_12952                                -0.902851  ...
#
#               17Networks_RH_DorsAttnB_PostC_14 NZMean_Zscore  \
# Subject
# 100522_12003                                             NaN
# 100522_12371                                             NaN
# 100522_12783                                             NaN
# 102041_12037                                       -0.007455
# 102041_12500                                        0.214304
# ...                                                      ...
# 96902_11903                                         1.169752
# 96902_12440                                              NaN
# 96902_12788                                              NaN
# 98370_12558                                         0.263404
# 98370_12952                                        -0.270031
#
#               17Networks_RH_SalVentAttnA_ParMed_10 NZMean_Zscore  \
# Subject
# 100522_12003                                                NaN
# 100522_12371                                                NaN
# 100522_12783                                                NaN
# 102041_12037                                          -1.744736
# 102041_12500                                           0.165705
# ...                                                         ...
# 96902_11903                                            0.151322
# 96902_12440                                                 NaN
# 96902_12788                                            1.193155
# 98370_12558                                            0.516865
# 98370_12952                                           -0.304621
#
#               17Networks_RH_ContC_pCun_8 NZMean_Zscore  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  1.422448
# 102041_12500                                 -0.642590
# ...                                                ...
# 96902_11903                                   0.292169
# 96902_12440                                        NaN
# 96902_12788                                        NaN
# 98370_12558                                   0.608080
# 98370_12952                                  -0.073080
#
#               17Networks_RH_ContC_pCun_9 NZMean_Zscore  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  1.332690
# 102041_12500                                  0.554415
# ...                                                ...
# 96902_11903                                   0.316984
# 96902_12440                                        NaN
# 96902_12788                                   1.064469
# 98370_12558                                   0.664337
# 98370_12952                                   0.435092
#
#               17Networks_RH_ContC_pCun_10 NZMean_Zscore  \
# Subject
# 100522_12003                                        NaN
# 100522_12371                                        NaN
# 100522_12783                                        NaN
# 102041_12037                                        NaN
# 102041_12500                                   0.571277
# ...                                                 ...
# 96902_11903                                    1.379599
# 96902_12440                                         NaN
# 96902_12788                                         NaN
# 98370_12558                                    0.724690
# 98370_12952                                   -1.036934
#
#               17Networks_RH_ContC_pCun_11 NZMean_Zscore  \
# Subject
# 100522_12003                                        NaN
# 100522_12371                                        NaN
# 100522_12783                                        NaN
# 102041_12037                                  -1.331926
# 102041_12500                                   0.192287
# ...                                                 ...
# 96902_11903                                    0.590506
# 96902_12440                                         NaN
# 96902_12788                                         NaN
# 98370_12558                                    0.574936
# 98370_12952                                    0.041844
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZMean_Zscore  \
# Subject
# 100522_12003                                             NaN
# 100522_12371                                             NaN
# 100522_12783                                             NaN
# 102041_12037                                        1.217099
# 102041_12500                                       -0.090248
# ...                                                      ...
# 96902_11903                                         0.631885
# 96902_12440                                              NaN
# 96902_12788                                              NaN
# 98370_12558                                         0.618616
# 98370_12952                                         0.241250
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZMean_Zscore  \
# Subject
# 100522_12003                                              NaN
# 100522_12371                                              NaN
# 100522_12783                                              NaN
# 102041_12037                                        -0.114782
# 102041_12500                                         0.302797
# ...                                                       ...
# 96902_11903                                         -0.099779
# 96902_12440                                               NaN
# 96902_12788                                               NaN
# 98370_12558                                          1.382927
# 98370_12952                                          0.350944
#
#               Subject_Avg_NZMean_Zscore  Subject_Std_NZMean_Zscore
# Subject
# 100522_12003                        0.0                  -2.467815
# 100522_12371                        0.0                  -3.219878
# 100522_12783                        0.0                  -2.954697
# 102041_12037                        0.0                  -4.445529
# 102041_12500                        0.0                  -4.770447
# ...                                 ...                        ...
# 96902_11903                         0.0                  -4.311151
# 96902_12440                         0.0                  -4.217319
# 96902_12788                         0.0                  -2.720344
# 98370_12558                         0.0                  -4.248202
# 98370_12952                         0.0                  -5.018012
#
# [172 rows x 69 columns]
#                 group  17Networks_RH_VisCent_Striate_2 NZMean_Zscore  \
# Subject
# 100522_12003    TD/NC                                            NaN
# 100522_12371    TD/NC                                            NaN
# 100522_12783    TD/NC                                            NaN
# 102041_12037  PRO/CHR                                      -0.575993
# 102041_12500  PRO/CHR                                       1.012253
# ...               ...                                            ...
# 96902_11903     TD/NC                                       1.158070
# 96902_12440     TD/NC                                            NaN
# 96902_12788     TD/NC                                            NaN
# 98370_12558     TD/NC                                       0.920255
# 98370_12952     TD/NC                                       0.568543
#
#               17Networks_RH_VisCent_ExStr_14 NZMean_Zscore  \
# Subject
# 100522_12003                                      2.062694
# 100522_12371                                           NaN
# 100522_12783                                           NaN
# 102041_12037                                     -0.273239
# 102041_12500                                      2.120714
# ...                                                    ...
# 96902_11903                                       1.542401
# 96902_12440                                            NaN
# 96902_12788                                            NaN
# 98370_12558                                       0.267558
# 98370_12952                                      -0.098681
#
#               17Networks_RH_VisCent_ExStr_17 NZMean_Zscore  \
# Subject
# 100522_12003                                      2.060480
# 100522_12371                                      3.018645
# 100522_12783                                      2.521392
# 102041_12037                                     -1.079381
# 102041_12500                                      0.951709
# ...                                                    ...
# 96902_11903                                       1.175771
# 96902_12440                                       0.237820
# 96902_12788                                       1.620236
# 98370_12558                                       0.118022
# 98370_12952                                       0.080610
#
#               17Networks_RH_VisPeri_StriCal_3 NZMean_Zscore  \
# Subject
# 100522_12003                                       1.429281
# 100522_12371                                       1.712605
# 100522_12783                                       2.095431
# 102041_12037                                       0.054191
# 102041_12500                                       1.400187
# ...                                                     ...
# 96902_11903                                        1.659552
# 96902_12440                                        1.316897
# 96902_12788                                        2.242383
# 98370_12558                                        0.798168
# 98370_12952                                        0.676402
#
#               17Networks_RH_VisPeri_StriCal_5 NZMean_Zscore  \
# Subject
# 100522_12003                                            NaN
# 100522_12371                                            NaN
# 100522_12783                                            NaN
# 102041_12037                                       0.388867
# 102041_12500                                       1.085037
# ...                                                     ...
# 96902_11903                                        0.854854
# 96902_12440                                             NaN
# 96902_12788                                             NaN
# 98370_12558                                        1.685164
# 98370_12952                                        1.214670
#
#               17Networks_RH_VisPeri_ExStrInf_7 NZMean_Zscore  \
# Subject
# 100522_12003                                        2.939193
# 100522_12371                                        1.387559
# 100522_12783                                        2.333393
# 102041_12037                                        0.833441
# 102041_12500                                        1.347762
# ...                                                      ...
# 96902_11903                                         0.798626
# 96902_12440                                         1.118972
# 96902_12788                                              NaN
# 98370_12558                                         2.362108
# 98370_12952                                         0.691403
#
#               17Networks_RH_VisPeri_ExStrSup_3 NZMean_Zscore  \
# Subject
# 100522_12003                                        0.329546
# 100522_12371                                             NaN
# 100522_12783                                             NaN
# 102041_12037                                       -1.146407
# 102041_12500                                        0.932718
# ...                                                      ...
# 96902_11903                                         0.311710
# 96902_12440                                              NaN
# 96902_12788                                         2.467661
# 98370_12558                                         0.131769
# 98370_12952                                         0.175525
#
#               17Networks_RH_SomMotA_6 NZMean_Zscore  \
# Subject
# 100522_12003                                    NaN
# 100522_12371                                    NaN
# 100522_12783                                    NaN
# 102041_12037                               1.321019
# 102041_12500                              -0.727051
# ...                                             ...
# 96902_11903                               -0.091523
# 96902_12440                                     NaN
# 96902_12788                                0.151524
# 98370_12558                                0.351100
# 98370_12952                               -0.301814
#
#               17Networks_RH_SomMotA_12 NZMean_Zscore  ...  \
# Subject                                               ...
# 100522_12003                                     NaN  ...
# 100522_12371                                0.057445  ...
# 100522_12783                                     NaN  ...
# 102041_12037                                1.290677  ...
# 102041_12500                               -0.620890  ...
# ...                                              ...  ...
# 96902_11903                                 0.258562  ...
# 96902_12440                                 0.497216  ...
# 96902_12788                                 0.318467  ...
# 98370_12558                                 0.346654  ...
# 98370_12952                                -0.415755  ...
#
#               17Networks_RH_DorsAttnB_PostC_14 NZMean_Zscore  \
# Subject
# 100522_12003                                             NaN
# 100522_12371                                             NaN
# 100522_12783                                             NaN
# 102041_12037                                       -0.007455
# 102041_12500                                        0.214304
# ...                                                      ...
# 96902_11903                                         1.169752
# 96902_12440                                              NaN
# 96902_12788                                              NaN
# 98370_12558                                         0.263404
# 98370_12952                                        -0.270031
#
#               17Networks_RH_SalVentAttnA_ParMed_10 NZMean_Zscore  \
# Subject
# 100522_12003                                                NaN
# 100522_12371                                                NaN
# 100522_12783                                                NaN
# 102041_12037                                          -1.744736
# 102041_12500                                           0.165705
# ...                                                         ...
# 96902_11903                                            0.151322
# 96902_12440                                                 NaN
# 96902_12788                                            1.193155
# 98370_12558                                            0.516865
# 98370_12952                                           -0.304621
#
#               17Networks_RH_ContC_pCun_8 NZMean_Zscore  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  1.422448
# 102041_12500                                 -0.642590
# ...                                                ...
# 96902_11903                                   0.292169
# 96902_12440                                        NaN
# 96902_12788                                        NaN
# 98370_12558                                   0.608080
# 98370_12952                                  -0.073080
#
#               17Networks_RH_ContC_pCun_9 NZMean_Zscore  \
# Subject
# 100522_12003                                       NaN
# 100522_12371                                       NaN
# 100522_12783                                       NaN
# 102041_12037                                  1.332690
# 102041_12500                                  0.554415
# ...                                                ...
# 96902_11903                                   0.316984
# 96902_12440                                        NaN
# 96902_12788                                   1.064469
# 98370_12558                                   0.664337
# 98370_12952                                   0.435092
#
#               17Networks_RH_ContC_pCun_10 NZMean_Zscore  \
# Subject
# 100522_12003                                        NaN
# 100522_12371                                        NaN
# 100522_12783                                        NaN
# 102041_12037                                        NaN
# 102041_12500                                   0.571277
# ...                                                 ...
# 96902_11903                                    1.379599
# 96902_12440                                         NaN
# 96902_12788                                         NaN
# 98370_12558                                    0.724690
# 98370_12952                                   -1.036934
#
#               17Networks_RH_ContC_pCun_11 NZMean_Zscore  \
# Subject
# 100522_12003                                        NaN
# 100522_12371                                        NaN
# 100522_12783                                        NaN
# 102041_12037                                  -1.331926
# 102041_12500                                   0.192287
# ...                                                 ...
# 96902_11903                                    0.590506
# 96902_12440                                         NaN
# 96902_12788                                         NaN
# 98370_12558                                    0.574936
# 98370_12952                                    0.041844
#
#               17Networks_RH_DefaultA_pCunPCC_5 NZMean_Zscore  \
# Subject
# 100522_12003                                             NaN
# 100522_12371                                             NaN
# 100522_12783                                             NaN
# 102041_12037                                        1.217099
# 102041_12500                                       -0.090248
# ...                                                      ...
# 96902_11903                                         0.631885
# 96902_12440                                              NaN
# 96902_12788                                              NaN
# 98370_12558                                         0.618616
# 98370_12952                                         0.241250
#
#               17Networks_RH_DefaultA_pCunPCC_12 NZMean_Zscore  \
# Subject
# 100522_12003                                              NaN
# 100522_12371                                              NaN
# 100522_12783                                              NaN
# 102041_12037                                        -0.114782
# 102041_12500                                         0.302797
# ...                                                       ...
# 96902_11903                                         -0.099779
# 96902_12440                                               NaN
# 96902_12788                                               NaN
# 98370_12558                                          1.382927
# 98370_12952                                          0.350944
#
#               Subject_Avg_NZMean_Zscore  Subject_Std_NZMean_Zscore
# Subject
# 100522_12003                        0.0                  -2.467815
# 100522_12371                        0.0                  -3.219878
# 100522_12783                        0.0                  -2.954697
# 102041_12037                        0.0                  -4.445529
# 102041_12500                        0.0                  -4.770447
# ...                                 ...                        ...
# 96902_11903                         0.0                  -4.311151
# 96902_12440                         0.0                  -4.217319
# 96902_12788                         0.0                  -2.720344
# 98370_12558                         0.0                  -4.248202
# 98370_12952                         0.0                  -5.018012
#
# [172 rows x 70 columns]

# %%
cestmat2=cestmat.copy()
NMDAmat2=NMDAmat.copy()
GABAmat2=GABAmat.copy()
mGluR5mat2=mGluR5mat.copy()
cestmat2.columns = [f"GluCEST_{col}" if "NZ" in col else col for col in cestmat2.columns]
NMDAmat2.columns = [f"NMDA_{col}" if "NZ" in col else col for col in NMDAmat2.columns]
GABAmat2.columns = [f"GABA_{col}" if "NZ" in col else col for col in GABAmat2.columns]
mGluR5mat2.columns = [f"mGluR5_{col}" if "NZ" in col else col for col in mGluR5mat2.columns]

# Align dataframes by "Subject" index and concatenate along columns
grp_df = cestmat2.join(NMDAmat2.filter(like='NZ'), how='left')
grp_df = grp_df.join(GABAmat2.filter(like='NZ'), how='left')
grp_df = grp_df.join(mGluR5mat2.filter(like='NZ'), how='left')

# Save grp_df
grp_df.to_csv(outpath + '/grp_df_' + dataset + atlas + '.csv', index=True)

# %%
# Start with Loop through subjects. 
# Find path to 

I have parcel-wise glucest values and I want to normalize based on that subject's average glucest value.
Loop through rows of df
subj= the index of that row. 
Get average glucest value from path that includes subj in the path name

# Transpose receptor maps.
nmda = NMDAmat.T
gaba = GABAmat.T
mglur5 = mGluR5mat.T

# Keep only parcels contained in cestmat
cestmat_regions = [col.replace(' NZMean', '') for col in cestmat.columns if ' NZMean' in col]
nmda_filtered = nmda[[col for col in nmda.columns if col in cestmat_regions]]
gaba_filtered = gaba[[col for col in gaba.columns if col in cestmat_regions]]
mglur5_filtered = mglur5[[col for col in mglur5.columns if col in cestmat_regions]]

# Filtered columns
nmda_filtered.columns = [f"NMDA_{col}" for col in nmda_filtered.columns]
gaba_filtered.columns = [f"GABA_{col}" for col in gaba_filtered.columns]
mglur5_filtered.columns = [f"mGluR5_{col}" for col in mglur5_filtered.columns]

# Repeat values for length of cestmat
nmda_repeated = pd.concat([nmda_filtered] * len(cestmat), ignore_index=True)
gaba_repeated = pd.concat([gaba_filtered] * len(cestmat), ignore_index=True)
mglur5_repeated = pd.concat([mglur5_filtered] * len(cestmat), ignore_index=True)

# Concatenate
grp_df_std = pd.concat([cestmat2, nmda_repeated, gaba_repeated, mglur5_repeated], axis=1)

# Save grp_df_std
grp_df_std.to_csv(outpath + '/grp_df_std' + dataset + atlas + '.csv', index=True)
print(grp_df_std)
