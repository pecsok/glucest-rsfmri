# %% [markdown]
# ## In this notebook:
# #### We import PET-derived volumetric receptor maps and parcellate using the Schaefer100 atlas.
#
# 1. Import packages and maps
# 2. Parcellate

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
from nilearn.datasets import fetch_atlas_schaefer_2018
from neuromaps.parcellate import Parcellater
import warnings
from neuromaps.datasets import fetch_fslr, fetch_annotation
from neuromaps import datasets, images, nulls, resampling, stats, transforms, parcellate
from neuromaps.parcellate import Parcellater 
from neuromaps.resampling import resample_images
from neuromaps.images import dlabel_to_gifti
import neuromaps
import nibabel as nib
import os
import numpy as np
import mayavi
from PIL import Image
import hcp_utils as hcp
import nilearn.plotting as plotting
import warnings
from netneurotools.datasets import fetch_cammoun2012
from netneurotools import datasets as nntdata
#import abagen ## This is important for certification purposes 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Set Variables

# %%
atlas = 'schaefer' #'cammoun2012'

if atlas == 'cammoun2012':
    cammoun = fetch_cammoun2012()
    scale = 'scale500'
    print(cammoun)
elif atlas == 'schaefer':
    scale = 'scale1000_17'
    schaefer = fetch_atlas_schaefer_2018(n_rois=1000, yeo_networks=17)
    print(schaefer['maps'])


path = "/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/data/maps/PET_nifti_images/"
outpath = "/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/data/parcellated/PET_parcellated/"+atlas+"_"+scale+"/"
# Out:
# /Users/pecsok/nilearn_data/schaefer_2018/Schaefer2018_1000Parcels_17Networks_order_FSLMNI152_1mm.nii.gz

# %% [markdown]
# ### Load in maps of interest

# %%
receptors_nii = [path+'GABAa-bz_flumazenil_hc16_norgaard.nii',
                 path+'GABAa_flumazenil_hc6_dukart.nii',
                 path+'mGluR5_abp_hc22_rosaneto.nii',
                 path+'mGluR5_abp_hc28_dubois.nii',
                 path+'mGluR5_abp_hc73_smart.nii',
                 path+'NMDA_ge179_hc29_galovic.nii.gz'] #FIX add back Dopa


# Surface Annotations
fslrANNOTATIONS = [
    ('sydnor2021', 'SAaxis', 'fsLR', '32k'), # SA Axis
    ('hcps1200', 'thickness', 'fsLR', '32k'), # Cortical Thickness
    ('raichle', 'cbf', 'fsLR', '164k'), # Cerebral blood flow
    ('raichle', 'cbv', 'fsLR', '164k'), # Cerebral blood volume
    ('raichle', 'cmr02', 'fsLR', '164k'), # Oxygen metabolism
    ('raichle', 'cmrglc', 'fsLR', '164k')] # Glucose metabolism

fsaverageANNOTATIONS = [
    ('abagen', 'genepc1', 'fsaverage', '10k')] # PC1 of Allen Brain Atlas genes

annots = ['SAaxis','CThick','CBF','CBV','O2met','Glucose','abaPC1']

# %% [markdown]
# ### Parcellate

# %%
if atlas == 'cammoun2012':
    parcellated = {}
    parcellater = Parcellater(cammoun[scale], 'MNI152')
    for receptor in receptors_nii:
        parcellated[receptor] = parcellater.fit_transform(receptor, 'MNI152', True)
        print(parcellated[receptor])
        print(parcellated[receptor].shape)
        name = receptor.split('/')[-1]  # get nifti file name
        name = name.split('.')[0]  # remove .nii
        np.savetxt(outpath+name+'.csv', parcellated[receptor], delimiter=',')

elif atlas == 'schaefer':  
    parcellated = {}
    parcellater = Parcellater(schaefer['maps'], 'MNI152')
    for receptor in receptors_nii:
        parcellated[receptor] = parcellater.fit_transform(receptor, 'MNI152', True)
        #print(parcellated[receptor])
        print(parcellated[receptor].shape)
        name = receptor.split('/')[-1]  # get nifti file name
        name = name.split('.')[0]  # remove .nii
        np.savetxt(outpath+name+'.csv', parcellated[receptor], delimiter=',')
# Out:
# (1, 1000)
# (1, 1000)
# (1, 1000)
# (1, 1000)
# (1, 1000)
# (1, 1000)

# %%
#sa_path = "/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/results"

# Surface Annotations

#saaxis = datasets.fetch_annotation(source='sydnor2021', desc='SAaxis', space='fsLR', den='32k')
# transform saaxis from fslr to fsaverage
#saaxis_surface10k = transforms.fslr_to_fsaverage(saaxis, target_density='10k',
#                                                  hemi=None,
#                                                  method='linear')


# Load in fslr annotations
imgs=[]
for (src, desc, space, den) in fslrANNOTATIONS:
    img = datasets.fetch_annotation(source=src, desc=desc,
                                    space=space, den=den)
    imgs.append(img)                

# Transform to 10k space
imgs_10k=[]
for img in imgs:
    img_10k = transforms.fslr_to_fsaverage(img, target_density='10k',
                                           hemi=None,
                                           method='linear')
    imgs_10k.append(img_10k)

# Add 10k annotation
for (src, desc, space, den) in fsaverageANNOTATIONS:
    img_10k = datasets.fetch_annotation(source=src, desc=desc,
                                        space=space, den=den)
    imgs_10k.append(img_10k)

# %%
atlas = 'schaefer1000'
scale = 'scale1000_17'

if atlas == 'schaefer1000':
    schaefer = nntdata.fetch_schaefer2018(version='fsaverage5')['1000Parcels17Networks']
    parc_gifti = images.annot_to_gifti(schaefer)
    #print(parc_gifti.shape)
    parc = Parcellater(parc_gifti, 'fsaverage')
    for i in range(len(annots)):
        annot = annots[i]
        img_10k = imgs_10k[i]
        parcellated_img = parc.fit_transform(img_10k, 'fsaverage')
        #print(parcellated_img)
        if annot == 'SAaxis':
            order = parcellated_saaxis.argsort()
            parcellated_sa_ranks = order.argsort()
            # Save output as df. Add index numbered 1-1000 called Parcel and df as column, "SAaxis rank"
            sa_df = pd.DataFrame({
                "Parcel": np.arange(1, len(parcellated_sa_ranks) + 1),
                "SAaxis_rank": parcellated_sa_ranks})
            sa_df.to_csv(outpath+'/SAaxis_data_scale1000_17N.csv', index=True, header=True)
        else:
            print(parcellated_img.shape)
            np.savetxt(outpath+annot+'_fsavg_values.csv', parcellated_img, delimiter=',')
# Out:
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# '\n        \n        # parcellated values aren\'t integers, but we can get their rankings instead\n        order = parcellated_saaxis.argsort()\n        parcellated_sa_ranks = order.argsort()\n        print(parcellated_sa_ranks)\n\n\n\n\n\n        \n\n# Generate an empty list to add transformed maps\nnmaps_transformed = []\nnmaps_transformed_array = []\nif atlas ==\'cammoun2012\':\n    # convert cammoun to fsaverage\n    cammoun_fsavg = transforms.mni152_to_fsaverage(cammoun, \'10k\')\n                                                  #hemi=None,\n                                                  #method=\'linear\')\n    #parc_gifti = images.annot_to_gifti(cammoun_fsavg)\n    parc = Parcellater(cammoun_fsavg, \'fsaverage\')\n    parc = Parcellater(parc_gifti, \'fsaverage\')\n    parcellated_saaxis = parc.fit_transform(saaxis_surface10k, \'fsaverage\')\n    # parcellated values aren\'t integers, but we can get their rankings instead\n    order = parcellated_saaxis.argsort()\n    parcellated_sa_ranks = order.argsort()\n    print(parcellated_sa_ranks)\n    print(parcellated_sa_ranks.shape)\n    sa_df = pd.DataFrame({\n        "Parcel": np.arange(1, len(parcellated_sa_ranks) + 1),\n        "SAaxis_rank": parcellated_sa_ranks})\n    sa_df.to_csv(sa_path+\'/SAaxis_data_cammoun500.csv\', index=True, header=True)\n\n\nelif atlas == \'schaefer1000\':\n    schaefer = nntdata.fetch_schaefer2018(version=\'fsaverage5\')[\'1000Parcels17Networks\']\n    parc_gifti = images.annot_to_gifti(schaefer)\n    #print(parc_gifti.shape)\n    parc = Parcellater(parc_gifti, \'fsaverage\')\n    parcellated_saaxis = parc.fit_transform(saaxis_surface10k, \'fsaverage\')\n    # parcellated values aren\'t integers, but we can get their rankings instead\n    order = parcellated_saaxis.argsort()\n    parcellated_sa_ranks = order.argsort()\n    print(parcellated_sa_ranks)\n    # Save output as df. Add index numbered 1-1000 called Parcel and df as column, "SAaxis rank"\n    sa_df = pd.DataFrame({\n        "Parcel": np.arange(1, len(parcellated_sa_ranks) + 1),\n        "SAaxis_rank": parcellated_sa_ranks})\n    sa_df.to_csv(sa_path+\'/SAaxis_data_scale1000_17N.csv\', index=True, header=True)\n'

# %%
sa_path = "/Users/pecsok/projects/Neuromaps/pecsok_pfns/neuromaps/results"

# SA Axis 
saaxis = datasets.fetch_annotation(source='sydnor2021', desc='SAaxis', space='fsLR', den='32k')
# transform saaxis from fslr to fsaverage
saaxis_surface10k = transforms.fslr_to_fsaverage(saaxis, target_density='10k',
                                                  hemi=None,
                                                  method='linear')

if atlas =='cammoun2012':
    # convert cammoun to fsaverage
    cammoun_fsavg = transforms.mni152_to_fsaverage(cammoun, '10k')
                                                  #hemi=None,
                                                  #method='linear')
    #parc_gifti = images.annot_to_gifti(cammoun_fsavg)
    parc = Parcellater(cammoun_fsavg, 'fsaverage')
    parc = Parcellater(parc_gifti, 'fsaverage')
    parcellated_saaxis = parc.fit_transform(saaxis_surface10k, 'fsaverage')
    # parcellated values aren't integers, but we can get their rankings instead
    order = parcellated_saaxis.argsort()
    parcellated_sa_ranks = order.argsort()
    print(parcellated_sa_ranks)
    print(parcellated_sa_ranks.shape)
    sa_df = pd.DataFrame({
        "Parcel": np.arange(1, len(parcellated_sa_ranks) + 1),
        "SAaxis_rank": parcellated_sa_ranks})
    sa_df.to_csv(sa_path+'/SAaxis_data_cammoun500.csv', index=True, header=True)

elif atlas == 'schaefer1000':
    schaefer = nntdata.fetch_schaefer2018(version='fsaverage5')['1000Parcels17Networks']
    parc_gifti = images.annot_to_gifti(schaefer)
    #print(parc_gifti.shape)
    parc = Parcellater(parc_gifti, 'fsaverage')
    parcellated_saaxis = parc.fit_transform(saaxis_surface10k, 'fsaverage')
    # parcellated values aren't integers, but we can get their rankings instead
    order = parcellated_saaxis.argsort()
    parcellated_sa_ranks = order.argsort()
    print(parcellated_sa_ranks)
    # Save output as df. Add index numbered 1-1000 called Parcel and df as column, "SAaxis rank"
    sa_df = pd.DataFrame({
        "Parcel": np.arange(1, len(parcellated_sa_ranks) + 1),
        "SAaxis_rank": parcellated_sa_ranks})
    sa_df.to_csv(sa_path+'/SAaxis_data_scale1000_17N.csv', index=True, header=True)
# Out:
# [541 324 372 218 410 235 355 178 184 115 117 318 174  99 215 121  69 163
#   51 276 396 133  46 209  50  58  48 151 260  66 186  75 200 243  22 226
#   35 130   0  36 296 228   5 144 291   9   2 392 198 109   1   3 267   6
#  336  43  14  96 274  24 341   8 232 204 379  83  42  54  56 110  94 214
#   76 326 119  87 247 136  89 199 255 586 486 309 313 256 493 539 246 401
#  310 399 317 535 381 238 202 171 360 531 475 193 364 524 268 329 277 339
#  241 265 452 383 343 177 217 224 118 172 273 300 150 147 439 408 120 261
#  123 244 146 167  44 156  34 194 145 249  63 149  25 221 105 161  79 279
#  135 216  55  88  29 132 166 122 106  86  12 190 195  95  57 225  59 128
#  208 262  47 113 134  33 112 157  73  39 628 731 573 564 572 824 448 470
#  666 345 230 425 434 485 561 558 346 213 518 242 353 676 432 530 492 427
#  212 311 293 449 464 488 491 348 271 398 361 258 333 344 357 278 350 385
#  351 269 266 295 321 288 444 665 504 544 645 424 429 597 469 718 590 384
#  673 523 634 633 897 471 817 687 508 474 395 563 773 752 688 686 793 719
#  764 543 622 647 589 533 417 685 352 549 330 468 420 591 547 872 884 765
#  654 579 577 706 703 497 320 451 585 201 422 282 203 623 298 542 536 334
#  620 691 738 723 757 596 805 814 743 758 761 696 819 841 652 776 669 684
#  750 603 664 745 602 636 715 510 630 583 565 527 861 850 650 853 744 720
#  717 592 608 601 559 587 450 521 891 870 994 898 755 937 871 947 795 875
#  868 707 671 925 694 724 797 807 734 926 749 936 862 956 756 889 852 896
#  430 354 397 371 442 482 457 433 373 369 560 515 913 762 575 682 726 675
#  732 950 939 826 733 835 976 699 944 778 828 918 670 954 766 881 953 920
#  985 806 999 829 998 974 977 827 989 725 815 637 796 648 629 714 667 641
#  605 822 695 804 931 917 986 860 921 701 919 982 901 935 952 711 856 846
#  721 916 968 760 914 619 818 529 877 969 863 864 885 892 981 979 911 924
#  949 990 922 987 973 984 770 955 910 874 932 929 858 716 810 393 502 463
#  479 625 466 386 730 316 655 532 775 551 837 690 845 618 616 878 767 709
#  948 556 489 780 545 783 555 505 454 552 437 537 337 390 467 414 478 315
#  362 284 253 205 154 322 179 159 248 140 124 191  91 102 223 127 358  80
#   62  77  19 263  84  31  61 183 170  65 107 237 299  49 152  11 323  70
#  181 290  85   4 162  16  93 446 335  26 207 314  32  13  30 406 185  90
#   18 377  37 192  71  45 153 400 139  74 210 103 126 412 108 405  78 227
#  176 155 142 211 182 668 663 569 576 473 490 554 689 285 378 453 546 513
#  525 413 307 461 347 250 305 382 259 500 419 189 301 294 233 270 416 409
#  340 366 292 275 164 328 101 325 287 220  68 125 251 534 141 252  82 131
#  283 303 447 222  52  81 116 281 231  72 160 148  15  17 375 158 169 173
#   28 175 165   7 168  21 100 129 197  92  10 111  40 187 143 180 137  23
#   20 234 104 206  97 219 114  67 240  41  60 196  27  98  38 138  53  64
#  646 519 722 418 809 624 782 376 374 570 421 522 465 388 456 264 501 584
#  496 512 229 356 440 445 507 389 245 306 562 312 472 455 426 435 280 368
#  239 503 308 319 480 370 297 254 257 342 438 338 302 272 332 363 431 567
#  606 289 458 359 642 753 511 772 498 538 517 653 481 387 528 459 495 441
#  484 712 610 635 423 785 678 599 477 540 611 649 626 759 672 698 774 808
#  729 697 632 700 612 840 614 656 436 571 415 692 487 651 568 873 842 728
#  566 514 821 615 679 593 483 411 365 659 236 304 188 639 402 391 367 574
#  286 736 677 748 768 742 812 786 638 787 820 849 839 915 811 644 704 777
#  739 674 594 621 737 708 781 895 509 640 598 609 404 680 923 906 816 582
#  894 763 790 769 702 681 751 580 613 661 607 443 643 940 957 992 962 844
#  825 832 813 967 869 912 847 791 866 903 741 970 788 693 902 740 588 934
#  904 848 855 771 893 799 946 880 857 993 988 754 876 854 779 867 660 403
#  349 499 476 460 380 331 327 879 789 933 945 843 578 683 516 803 802 657
#  859 882 958 951 908 710 943 830 909 735 900 983 995 971 833 964 997 991
#  834 996 800 836 581 627 883 520 506 617 792 801 865 798 907 980 890 886
#  831 838 960 851 966 888 965 899 905 975 553 887 959 462 972 961 942 941
#  930 963 978 927 938 928 823 794 428 604 394 526 407 658 705 713 548 662
#  746 784 595 747 600 557 494 550 727 631]
# (1000,)

# %% [raw]
# print(imgs_10k)
